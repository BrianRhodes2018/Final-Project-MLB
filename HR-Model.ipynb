# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pickle

# %%
# Reference the file where the CSV is located
data = "cleanedData.csv"

# Import the data into a Pandas DataFrame
cleanerDF = pd.read_csv(data)
cleanerDF.head()
# Out:
#    Unnamed: 0  yearID  Rank    G  Ghome    W    L    R    AB     H ...   3B  \
# 0        1541    1970     5  162   81.0   76   86  736  5546  1495 ...   24
# 1        1542    1970     1  162   81.0  108   54  792  5545  1424 ...   25
# 2        1543    1970     3  162   81.0   87   75  786  5535  1450 ...   28
# 3        1544    1970     3  162   81.0   86   76  631  5532  1391 ...   40
# 4        1545    1970     6  162   84.0   56  106  633  5514  1394 ...   20
#
#     HR     BB     SO    SB   ER   ERA  CG  SV    E
# 0  160  522.0  736.0  58.0  688  4.33  45  24  141
# 1  179  717.0  952.0  84.0  517  3.15  60  31  117
# 2  203  594.0  855.0  50.0  622  3.87  38  44  156
# 3  114  447.0  922.0  69.0  566  3.48  21  49  127
# 4  123  477.0  872.0  53.0  722  4.54  20  30  165
#
# [5 rows x 21 columns]

# %%
# This lets me know that 2006 is about the last year in the 75% range for the training dataset
n = 76
cleanerDF.head(int(len(cleanerDF)*(n/100)))
# Out:
#       Unnamed: 0  yearID  Rank    G  Ghome    W    L    R    AB     H ...   \
# 0           1541    1970     5  162   81.0   76   86  736  5546  1495 ...
# 1           1542    1970     1  162   81.0  108   54  792  5545  1424 ...
# 2           1543    1970     3  162   81.0   87   75  786  5535  1450 ...
# 3           1544    1970     3  162   81.0   86   76  631  5532  1391 ...
# 4           1545    1970     6  162   84.0   56  106  633  5514  1394 ...
# 5           1546    1970     2  162   80.0   84   78  806  5491  1424 ...
# 6           1547    1970     1  162   81.0  102   60  775  5540  1498 ...
# 7           1548    1970     5  162   81.0   76   86  649  5463  1358 ...
# 8           1549    1970     4  162   81.0   79   83  666  5377  1282 ...
# 9           1550    1970     4  162   81.0   79   83  744  5574  1446 ...
# 10          1551    1970     4  162   79.0   65   97  611  5503  1341 ...
# 11          1552    1970     2  161   81.0   87   74  749  5606  1515 ...
# 12          1553    1970     1  162   81.0   98   64  744  5483  1438 ...
# 13          1554    1970     4  163   81.0   65   97  613  5395  1305 ...
# 14          1555    1970     6  162   80.0   73   89  687  5411  1284 ...
# 15          1556    1970     2  163   81.0   93   69  680  5492  1381 ...
# 16          1557    1970     3  162   82.0   83   79  695  5443  1358 ...
# 17          1558    1970     2  162   81.0   89   73  678  5376  1338 ...
# 18          1559    1970     5  161   80.0   73   88  594  5456  1299 ...
# 19          1560    1970     1  162   82.0   89   73  729  5637  1522 ...
# 20          1561    1970     6  162   81.0   63   99  681  5494  1353 ...
# 21          1562    1970     3  162   81.0   86   76  831  5578  1460 ...
# 22          1563    1970     4  162   81.0   76   86  744  5689  1497 ...
# 23          1564    1970     6  162   81.0   70   92  626  5460  1302 ...
# 24          1565    1971     3  162   82.0   82   80  643  5575  1434 ...
# 25          1566    1971     1  158   77.0  101   57  742  5303  1382 ...
# 26          1567    1971     3  162   80.0   85   77  691  5401  1360 ...
# 27          1568    1971     4  162   81.0   76   86  511  5495  1271 ...
# 28          1569    1971     3  162   81.0   79   83  617  5382  1346 ...
# 29          1570    1971     3  162   81.0   83   79  637  5438  1401 ...
# ...          ...     ...   ...  ...    ...  ...  ...  ...   ...   ... ...
# 976         2517    2006     5  162   81.0   62  100  757  5589  1515 ...
# 977         2518    2006     2  162   81.0   89   73  766  5609  1539 ...
# 978         2519    2006     2  162   81.0   88   74  820  5628  1552 ...
# 979         2520    2006     4  162   81.0   75   87  730  5433  1400 ...
# 980         2521    2006     1  162   81.0   96   66  801  5602  1608 ...
# 981         2522    2006     1  162   81.0   97   65  930  5651  1608 ...
# 982         2523    2006     1  162   81.0   97   65  834  5558  1469 ...
# 983         2524    2006     1  162   81.0   93   69  771  5500  1429 ...
# 984         2525    2006     2  162   81.0   85   77  865  5687  1518 ...
# 985         2526    2006     5  162   81.0   67   95  691  5558  1462 ...
# 986         2527    2006     1  162   81.0   88   74  731  5576  1465 ...
# 987         2528    2006     4  162   81.0   78   84  756  5670  1540 ...
# 988         2529    2006     3  161   81.0   76   85  746  5472  1418 ...
# 989         2530    2006     1  161   80.0   83   78  781  5522  1484 ...
# 990         2531    2006     5  162   81.0   61  101  689  5474  1395 ...
# 991         2532    2006     3  162   81.0   80   82  835  5659  1571 ...
# 992         2533    2006     2  162   81.0   87   75  809  5596  1591 ...
# 993         2534    2006     5  162   81.0   71   91  746  5495  1437 ...
# 994         2535    2007     1  162   81.0   90   72  712  5398  1350 ...
# 995         2536    2007     3  162   81.0   84   78  810  5689  1562 ...
# 996         2537    2007     4  162   81.0   69   93  756  5631  1529 ...
# 997         2538    2007     1  162   81.0   96   66  867  5589  1561 ...
# 998         2539    2007     4  162   81.0   72   90  693  5441  1341 ...
# 999         2540    2007     1  162   81.0   85   77  752  5643  1530 ...
# 1000        2541    2007     5  162   81.0   72   90  783  5607  1496 ...
# 1001        2542    2007     1  162   80.0   96   66  811  5604  1504 ...
# 1002        2543    2007     2  163   82.0   90   73  860  5691  1591 ...
# 1003        2544    2007     2  162   81.0   88   74  887  5757  1652 ...
# 1004        2545    2007     5  162   81.0   71   91  790  5627  1504 ...
# 1005        2546    2007     4  162   81.0   73   89  723  5605  1457 ...
#
#       3B   HR     BB      SO     SB   ER   ERA  CG  SV    E
# 0     24  160  522.0   736.0   58.0  688  4.33  45  24  141
# 1     25  179  717.0   952.0   84.0  517  3.15  60  31  117
# 2     28  203  594.0   855.0   50.0  622  3.87  38  44  156
# 3     40  114  447.0   922.0   69.0  566  3.48  21  49  127
# 4     20  123  477.0   872.0   53.0  722  4.54  20  30  165
# 5     44  179  607.0   844.0   39.0  599  3.76  59  25  137
# 6     45  191  547.0   984.0  115.0  592  3.69  32  60  151
# 7     23  183  503.0   909.0   25.0  630  3.91  34  35  133
# 8     38  148  656.0   825.0   29.0  658  4.09  33  39  133
# 9     47  129  598.0   911.0  114.0  685  4.23  36  35  140
# 10    41   97  514.0   958.0   97.0  615  3.78  30  25  152
# 11    67   87  541.0   841.0  138.0  619  3.82  37  42  135
# 1003  50  177  474.0  1054.0  103.0  735  4.57   1  44   99
# 1004  38  201  521.0  1332.0  105.0  793  4.94   0  40  137
# 1005  30  167  547.0  1043.0   65.0  761  4.68   2  38  103
#
# [1006 rows x 21 columns]

# %%
trainingDF = cleanerDF.drop(cleanerDF[cleanerDF.yearID > 2006].index)
testingDF  = cleanerDF.drop(cleanerDF[cleanerDF.yearID < 2007].index)
testingDF.head()
# Out:
#      Unnamed: 0  yearID  Rank    G  Ghome   W   L    R    AB     H ...   3B  \
# 994        2535    2007     1  162   81.0  90  72  712  5398  1350 ...   40
# 995        2536    2007     3  162   81.0  84  78  810  5689  1562 ...   27
# 996        2537    2007     4  162   81.0  69  93  756  5631  1529 ...   30
# 997        2538    2007     1  162   81.0  96  66  867  5589  1561 ...   35
# 998        2539    2007     4  162   81.0  72  90  693  5441  1341 ...   20
#
#       HR     BB      SO     SB   ER   ERA  CG  SV    E
# 994  171  532.0  1111.0  109.0  662  4.13   7  51  106
# 995  176  534.0  1149.0   64.0  665  4.11   1  36  107
# 996  142  500.0   939.0  144.0  827  5.17   4  30   79
# 997  166  689.0  1042.0   96.0  618  3.87   5  45   81
# 998  190  532.0  1149.0   78.0  763  4.77   9  42  108
#
# [5 rows x 21 columns]

# %%
X_train=trainingDF['ERA'].values.reshape(-1, 1)

y_train=trainingDF['W'].values.reshape(-1, 1)

X_test=testingDF["HR"].values.reshape(-1, 1)

y_test=testingDF["W"].values.reshape(-1, 1)

lm=LinearRegression()


lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.coef_
# Out:
# array([[0.11876973]])

# %%
lm.intercept_
# Out:
# array([62.30884994])

# %%
predictions = lm.predict(X_test)
print(f"True output: {y_test[0]}")
print(f"Predicted output: {predictions[0]}")
print(f"Prediction Error: {predictions[0]-y_test[0]}")
# Out:
# True output: [90]
# Predicted output: [82.61847427]
# Prediction Error: [-7.38152573]

# %%
X_train.shape
# Out:
# (994, 1)

# %%
y_train.shape
# Out:
# (994, 1)

# %%
x_min = X_train.min()
x_max = X_train.max()

# %%
y_min = y_train.min()
y_max = y_train.max()

# %%
y_min_actual = y_train.min()
y_max_actual = y_train.max()

# %%
y_min_predicted = lm.predict(x_min)
y_max_predicted = lm.predict(x_max)
print(f"Actual Min Value: {y_min_actual}")
print(f"Predicted Min Value: {y_min_predicted}")
print(f"Actual Max Value: {y_max_actual}")
print(f"Predicted Max Value: {y_max_predicted}")
# Out:
# Actual Min Value: 37
# Predicted Min Value: [[66.10948139]]
# Actual Max Value: 116
# Predicted Max Value: [[93.66405943]]

# %%
plt.scatter(X_test, y_test, c='blue', marker='+')
##plt.scatter(userInput, y, c='red')
plt.xlabel("Number of Home Runs")
plt.ylabel("Number of Wins")
plt.plot([x_min, x_max], [y_min, y_max], c='red')
#plt.scatter(userInput, y, c='red', marker='+')
#userInput

# %%
with open('home_runs_model_pickle','wb') as file:
    pickle.dump(lm,file)

# %%
userInput = lm.predict([[167]]) 
userInput
# Out:
# array([[82.14339533]])

# %%
lm.score(X_test, y_test)
# Out:
# 0.117721667350424
