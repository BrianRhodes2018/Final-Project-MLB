# %%
import pandas as pd

# %%
df = pd.read_csv('runsPlotData.csv')
runsData = df.loc[:, ["R", "W", "yearID", "franchID"]]
    # Format the data to send as json
    
for rows in runsData:
    data = {
    "Runs": runsData.R.values.tolist(), 
    "Wins": runsData.W.values.tolist(),
    "Label": runsData.values.tolist()
    }

# %%
data
# Out:
# {'Runs': [736,
#   792,
#   786,
#   631,
#   633,
#   806,
#   775,
#   649,
#   666,
#   744,
#   611,
#   749,
#   744,
#   613,
#   687,
#   680,
#   695,
#   678,
#   594,
#   729,
#   681,
#   831,
#   744,
#   626,
#   643,
#   742,
#   691,
#   511,
#   617,
#   637,
#   586,
#   543,
#   701,
#   585,
#   603,
#   663,
#   654,
#   534,
#   622,
#   648,
#   588,
#   691,
#   558,
#   788,
#   486,
#   706,
#   739,
#   537,
#   628,
#   519,
#   640,
#   454,
#   566,
#   685,
#   707,
#   472,
#   558,
#   708,
#   580,
#   584,
#   537,
#   493,
#   513,
#   557,
#   528,
#   604,
#   503,
#   691,
#   488,
#   662,
#   568,
#   461,
#   799,
#   754,
#   738,
#   629,
#   652,
#   614,
#   741,
#   680,
#   642,
#   681,
#   755,
#   675,
#   738,
#   708,
#   668,
#   641,
#   608,
#   758,
#   642,
#   704,
#   548,
#   739,
#   643,
#   619,
#   661,
#   659,
#   696,
#   618,
#   684,
#   669,
#   776,
#   662,
#   620,
#   653,
#   667,
#   798,
#   673,
#   647,
#   662,
#   671,
#   572,
#   689,
#   676,
#   751,
#   541,
#   634,
#   677,
#   690,
#   583,
#   682,
#   796,
#   628,
#   655,
#   712,
#   840,
#   688,
#   570,
#   664,
#   710,
#   648,
#   724,
#   675,
#   601,
#   681,
#   646,
#   758,
#   735,
#   712,
#   552,
#   659,
#   662,
#   714,
#   620,
#   619,
#   716,
#   550,
#   586,
#   611,
#   857,
#   615,
#   609,
#   625,
#   713,
#   608,
#   743,
#   570,
#   531,
#   730,
#   615,
#   686,
#   770,
#   708,
#   570,
#   595,
#   629,
#   616,
#   678,
#   719,
#   859,
#   675,
#   844,
#   692,
#   802,
#   676,
#   714,
#   680,
#   822,
#   769,
#   867,
#   639,
#   665,
#   831,
#   587,
#   605,
#   847,
#   734,
#   692,
#   624,
#   673,
#   737,
#   767,
#   605,
#   600,
#   659,
#   796,
#   691,
#   634,
#   664,
#   710,
#   639,
#   714,
#   605,
#   743,
#   727,
#   666,
#   804,
#   633,
#   735,
#   607,
#   532,
#   708,
#   684,
#   591,
#   614,
#   613,
#   600,
#   692,
#   590,
#   669,
#   757,
#   841,
#   866,
#   730,
#   706,
#   731,
#   760,
#   770,
#   583,
#   851,
#   739,
#   764,
#   807,
#   701,
#   734,
#   593,
#   573,
#   683,
#   775,
#   603,
#   711,
#   672,
#   731,
#   750,
#   613,
#   630,
#   805,
#   757,
#   698,
#   587,
#   614,
#   707,
#   738,
#   830,
#   637,
#   809,
#   663,
#   670,
#   811,
#   694,
#   820,
#   611,
#   686,
#   728,
#   666,
#   591,
#   610,
#   573,
#   738,
#   756,
#   624,
#   395,
#   429,
#   519,
#   476,
#   476,
#   370,
#   464,
#   431,
#   427,
#   394,
#   397,
#   450,
#   378,
#   493,
#   443,
#   421,
#   348,
#   458,
#   491,
#   407,
#   382,
#   426,
#   427,
#   464,
#   452,
#   329,
#   739,
#   774,
#   753,
#   814,
#   786,
#   676,
#   545,
#   683,
#   729,
#   569,
#   784,
#   691,
#   657,
#   891,
#   697,
#   709,
#   609,
#   691,
#   664,
#   724,
#   675,
#   651,
#   673,
#   685,
#   590,
#   651,
#   746,
#   799,
#   724,
#   722,
#   800,
#   701,
#   623,
#   704,
#   789,
#   643,
#   696,
#   654,
#   709,
#   764,
#   677,
#   770,
#   575,
#   708,
#   696,
#   659,
#   653,
#   558,
#   687,
#   679,
#   639,
#   795,
#   632,
#   681,
#   810,
#   696,
#   679,
#   762,
#   627,
#   761,
#   829,
#   693,
#   673,
#   580,
#   673,
#   641,
#   593,
#   758,
#   652,
#   738,
#   720,
#   615,
#   686,
#   682,
#   682,
#   652,
#   656,
#   750,
#   632,
#   818,
#   800,
#   732,
#   736,
#   686,
#   677,
#   729,
#   729,
#   706,
#   687,
#   682,
#   705,
#   690,
#   633,
#   839,
#   695,
#   757,
#   667,
#   568,
#   650,
#   719,
#   556,
#   747,
#   617,
#   759,
#   615,
#   708,
#   794,
#   786,
#   644,
#   680,
#   732,
#   831,
#   798,
#   654,
#   654,
#   638,
#   741,
#   667,
#   637,
#   797,
#   783,
#   731,
#   739,
#   663,
#   656,
#   718,
#   698,
#   601,
#   771,
#   809,
#   747,
#   729,
#   842,
#   770,
#   748,
#   720,
#   783,
#   742,
#   896,
#   648,
#   715,
#   635,
#   786,
#   862,
#   741,
#   788,
#   823,
#   806,
#   702,
#   723,
#   668,
#   760,
#   783,
#   798,
#   823,
#   845,
#   555,
#   550,
#   813,
#   714,
#   631,
#   660,
#   641,
#   666,
#   703,
#   617,
#   704,
#   628,
#   759,
#   682,
#   628,
#   772,
#   703,
#   800,
#   597,
#   651,
#   594,
#   664,
#   670,
#   578,
#   637,
#   763,
#   584,
#   708,
#   774,
#   669,
#   693,
#   702,
#   632,
#   604,
#   617,
#   647,
#   690,
#   554,
#   740,
#   707,
#   632,
#   698,
#   683,
#   712,
#   629,
#   637,
#   642,
#   694,
#   699,
#   632,
#   695,
#   731,
#   682,
#   669,
#   699,
#   690,
#   682,
#   690,
#   693,
#   732,
#   750,
#   573,
#   707,
#   728,
#   666,
#   732,
#   662,
#   603,
#   775,
#   733,
#   646,
#   733,
#   673,
#   640,
#   719,
#   599,
#   676,
#   767,
#   749,
#   686,
#   731,
#   653,
#   758,
#   695,
#   689,
#   576,
#   817,
#   605,
#   727,
#   665,
#   776,
#   799,
#   579,
#   674,
#   640,
#   760,
#   629,
#   768,
#   636,
#   702,
#   649,
#   651,
#   829,
#   684,
#   682,
#   705,
#   599,
#   579,
#   738,
#   593,
#   660,
#   674,
#   791,
#   608,
#   610,
#   548,
#   747,
#   740,
#   648,
#   733,
#   599,
#   745,
#   686,
#   693,
#   617,
#   679,
#   574,
#   631,
#   682,
#   780,
#   767,
#   786,
#   686,
#   684,
#   776,
#   738,
#   722,
#   790,
#   758,
#   899,
#   581,
#   716,
#   675,
#   675,
#   693,
#   733,
#   732,
#   821,
#   672,
#   715,
#   877,
#   707,
#   679,
#   734,
#   808,
#   758,
#   835,
#   847,
#   542,
#   589,
#   552,
#   543,
#   633,
#   500,
#   609,
#   679,
#   573,
#   652,
#   468,
#   602,
#   574,
#   532,
#   594,
#   547,
#   585,
#   670,
#   506,
#   549,
#   521,
#   466,
#   479,
#   569,
#   504,
#   535,
#   613,
#   566,
#   645,
#   704,
#   791,
#   801,
#   755,
#   693,
#   747,
#   840,
#   785,
#   654,
#   673,
#   747,
#   629,
#   634,
#   703,
#   740,
#   621,
#   749,
#   657,
#   730,
#   615,
#   629,
#   668,
#   796,
#   652,
#   563,
#   691,
#   642,
#   773,
#   949,
#   928,
#   762,
#   898,
#   772,
#   778,
#   952,
#   961,
#   783,
#   688,
#   753,
#   746,
#   703,
#   877,
#   894,
#   741,
#   871,
#   746,
#   861,
#   650,
#   776,
#   771,
#   993,
#   752,
#   759,
#   928,
#   766,
#   829,
#   791,
#   812,
#   851,
#   779,
#   687,
#   651,
#   868,
#   923,
#   784,
#   740,
#   777,
#   747,
#   742,
#   772,
#   681,
#   691,
#   891,
#   777,
#   764,
#   668,
#   725,
#   795,
#   925,
#   784,
#   689,
#   807,
#   654,
#   787,
#   665,
#   826,
#   817,
#   876,
#   861,
#   831,
#   750,
#   850,
#   826,
#   722,
#   667,
#   874,
#   714,
#   669,
#   707,
#   734,
#   644,
#   965,
#   706,
#   804,
#   713,
#   650,
#   749,
#   859,
#   845,
#   810,
#   620,
#   940,
#   816,
#   711,
#   908,
#   840,
#   851,
#   836,
#   777,
#   747,
#   865,
#   1009,
#   906,
#   747,
#   691,
#   823,
#   856,
#   793,
#   815,
#   686,
#   718,
#   900,
#   853,
#   893,
#   841,
#   775,
#   710,
#   859,
#   872,
#   809,
#   772,
#   945,
#   883,
#   864,
#   792,
#   810,
#   794,
#   792,
#   978,
#   764,
#   825,
#   950,
#   968,
#   823,
#   731,
#   938,
#   879,
#   798,
#   740,
#   748,
#   738,
#   871,
#   807,
#   947,
#   708,
#   793,
#   752,
#   907,
#   925,
#   887,
#   733,
#   848,
#   861,
#   691,
#   818,
#   729,
#   687,
#   772,
#   798,
#   777,
#   735,
#   897,
#   923,
#   724,
#   742,
#   847,
#   729,
#   758,
#   740,
#   771,
#   670,
#   804,
#   642,
#   884,
#   746,
#   657,
#   789,
#   927,
#   799,
#   814,
#   672,
#   890,
#   767,
#   851,
#   819,
#   708,
#   667,
#   859,
#   856,
#   706,
#   709,
#   739,
#   778,
#   575,
#   699,
#   749,
#   737,
#   713,
#   627,
#   768,
#   735,
#   897,
#   690,
#   800,
#   710,
#   641,
#   662,
#   814,
#   783,
#   787,
#   673,
#   843,
#   813,
#   736,
#   717,
#   907,
#   743,
#   961,
#   791,
#   724,
#   694,
#   699,
#   853,
#   591,
#   751,
#   805,
#   836,
#   574,
#   714,
#   801,
#   711,
#   877,
#   642,
#   768,
#   791,
#   753,
#   678,
#   795,
#   755,
#   876,
#   715,
#   826,
#   894,
#   836,
#   615,
#   803,
#   842,
#   949,
#   865,
#   789,
#   750,
#   858,
#   833,
#   827,
#   718,
#   803,
#   720,
#   761,
#   634,
#   780,
#   635,
#   897,
#   684,
#   793,
#   840,
#   680,
#   768,
#   698,
#   850,
#   855,
#   714,
#   860,
#   719,
#   696,
#   769,
#   729,
#   910,
#   741,
#   703,
#   820,
#   790,
#   740,
#   723,
#   717,
#   693,
#   701,
#   761,
#   685,
#   726,
#   688,
#   886,
#   722,
#   772,
#   807,
#   680,
#   684,
#   699,
#   649,
#   805,
#   750,
#   865,
#   775,
#   639,
#   773,
#   849,
#   768,
#   820,
#   868,
#   716,
#   749,
#   870,
#   813,
#   822,
#   758,
#   735,
#   757,
#   766,
#   820,
#   730,
#   801,
#   930,
#   834,
#   771,
#   865,
#   691,
#   731,
#   756,
#   746,
#   781,
#   689,
#   835,
#   809,
#   746,
#   712,
#   810,
#   756,
#   867,
#   693,
#   752,
#   ...],
#  'Wins': [76,
#   108,
#   87,
#   86,
#   56,
#   84,
#   102,
#   76,
#   79,
#   79,
#   65,
#   87,
#   98,
#   65,
#   73,
#   93,
#   83,
#   89,
#   73,
#   89,
#   63,
#   86,
#   76,
#   70,
#   82,
#   101,
#   85,
#   76,
#   79,
#   83,
#   79,
#   60,
#   91,
#   79,
#   85,
#   89,
#   74,
#   69,
#   71,
#   82,
#   83,
#   101,
#   67,
#   97,
#   61,
#   90,
#   90,
#   63,
#   70,
#   80,
#   85,
#   75,
#   87,
#   85,
#   95,
#   72,
#   86,
#   84,
#   76,
#   85,
#   77,
#   65,
#   70,
#   79,
#   83,
#   93,
#   59,
#   96,
#   58,
#   69,
#   75,
#   54,
#   76,
#   97,
#   89,
#   79,
#   77,
#   77,
#   99,
#   71,
#   85,
#   82,
#   88,
#   95,
#   81,
#   74,
#   79,
#   80,
#   82,
#   94,
#   71,
#   80,
#   60,
#   88,
#   81,
#   57,
#   88,
#   91,
#   84,
#   68,
#   80,
#   66,
#   98,
#   77,
#   72,
#   81,
#   77,
#   102,
#   82,
#   76,
#   79,
#   89,
#   71,
#   90,
#   80,
#   88,
#   60,
#   72,
#   86,
#   84,
#   67,
#   90,
#   95,
#   72,
#   75,
#   75,
#   108,
#   79,
#   57,
#   64,
#   91,
#   88,
#   76,
#   68,
#   75,
#   83,
#   82,
#   98,
#   86,
#   92,
#   71,
#   80,
#   82,
#   79,
#   70,
#   88,
#   83,
#   76,
#   64,
#   75,
#   102,
#   81,
#   74,
#   80,
#   90,
#   92,
#   85,
#   66,
#   55,
#   97,
#   86,
#   87,
#   101,
#   92,
#   73,
#   74,
#   72,
#   76,
#   61,
#   97,
#   97,
#   74,
#   90,
#   81,
#   88,
#   71,
#   74,
#   81,
#   102,
#   98,
#   84,
#   67,
#   75,
#   100,
#   64,
#   63,
#   101,
#   96,
#   69,
#   64,
#   75,
#   83,
#   94,
#   54,
#   69,
#   90,
#   99,
#   87,
#   71,
#   79,
#   92,
#   69,
#   86,
#   74,
#   92,
#   95,
#   73,
#   93,
#   76,
#   100,
#   66,
#   69,
#   90,
#   88,
#   84,
#   56,
#   89,
#   69,
#   87,
#   59,
#   66,
#   102,
#   91,
#   88,
#   73,
#   80,
#   90,
#   81,
#   85,
#   89,
#   85,
#   79,
#   82,
#   95,
#   95,
#   89,
#   63,
#   54,
#   84,
#   98,
#   68,
#   67,
#   71,
#   86,
#   83,
#   53,
#   81,
#   100,
#   83,
#   65,
#   70,
#   64,
#   89,
#   79,
#   84,
#   93,
#   97,
#   92,
#   77,
#   86,
#   90,
#   103,
#   67,
#   83,
#   91,
#   83,
#   73,
#   59,
#   75,
#   74,
#   76,
#   67,
#   50,
#   59,
#   59,
#   51,
#   54,
#   38,
#   66,
#   52,
#   60,
#   61,
#   50,
#   63,
#   41,
#   62,
#   60,
#   59,
#   41,
#   64,
#   59,
#   46,
#   41,
#   44,
#   56,
#   59,
#   57,
#   37,
#   89,
#   94,
#   89,
#   93,
#   87,
#   73,
#   61,
#   78,
#   83,
#   77,
#   90,
#   88,
#   60,
#   95,
#   86,
#   79,
#   65,
#   68,
#   89,
#   84,
#   81,
#   76,
#   87,
#   92,
#   64,
#   78,
#   88,
#   98,
#   78,
#   70,
#   99,
#   71,
#   74,
#   70,
#   92,
#   85,
#   79,
#   91,
#   70,
#   87,
#   82,
#   91,
#   68,
#   74,
#   90,
#   84,
#   81,
#   60,
#   79,
#   79,
#   77,
#   89,
#   80,
#   85,
#   86,
#   81,
#   74,
#   96,
#   70,
#   75,
#   104,
#   80,
#   84,
#   79,
#   81,
#   67,
#   78,
#   87,
#   90,
#   77,
#   81,
#   75,
#   92,
#   74,
#   66,
#   84,
#   69,
#   89,
#   66,
#   83,
#   81,
#   90,
#   85,
#   77,
#   89,
#   60,
#   84,
#   83,
#   91,
#   95,
#   77,
#   71,
#   84,
#   97,
#   98,
#   77,
#   75,
#   57,
#   83,
#   74,
#   62,
#   101,
#   62,
#   99,
#   72,
#   73,
#   95,
#   92,
#   72,
#   70,
#   86,
#   84,
#   87,
#   96,
#   76,
#   73,
#   71,
#   77,
#   78,
#   90,
#   108,
#   76,
#   86,
#   64,
#   74,
#   67,
#   83,
#   79,
#   87,
#   86,
#   69,
#   67,
#   78,
#   75,
#   77,
#   76,
#   84,
#   61,
#   98,
#   76,
#   83,
#   73,
#   85,
#   91,
#   91,
#   89,
#   92,
#   81,
#   80,
#   80,
#   65,
#   78,
#   90,
#   95,
#   75,
#   96,
#   54,
#   54,
#   89,
#   75,
#   71,
#   77,
#   87,
#   78,
#   88,
#   82,
#   84,
#   94,
#   91,
#   87,
#   81,
#   85,
#   100,
#   104,
#   65,
#   85,
#   83,
#   68,
#   83,
#   76,
#   70,
#   87,
#   63,
#   87,
#   83,
#   91,
#   69,
#   93,
#   75,
#   73,
#   59,
#   86,
#   92,
#   77,
#   80,
#   81,
#   81,
#   74,
#   87,
#   99,
#   67,
#   74,
#   89,
#   73,
#   92,
#   86,
#   83,
#   89,
#   65,
#   76,
#   88,
#   80,
#   94,
#   77,
#   91,
#   77,
#   79,
#   75,
#   75,
#   86,
#   74,
#   74,
#   85,
#   67,
#   91,
#   103,
#   77,
#   95,
#   75,
#   77,
#   85,
#   70,
#   83,
#   86,
#   94,
#   67,
#   84,
#   81,
#   87,
#   77,
#   74,
#   57,
#   84,
#   65,
#   82,
#   93,
#   95,
#   83,
#   71,
#   71,
#   77,
#   84,
#   78,
#   98,
#   84,
#   83,
#   75,
#   84,
#   85,
#   91,
#   98,
#   89,
#   73,
#   72,
#   86,
#   78,
#   90,
#   76,
#   75,
#   81,
#   72,
#   63,
#   90,
#   92,
#   87,
#   76,
#   72,
#   96,
#   70,
#   96,
#   82,
#   64,
#   72,
#   83,
#   77,
#   96,
#   104,
#   85,
#   80,
#   71,
#   94,
#   84,
#   73,
#   76,
#   67,
#   85,
#   64,
#   85,
#   84,
#   81,
#   71,
#   69,
#   94,
#   88,
#   59,
#   68,
#   97,
#   75,
#   61,
#   82,
#   103,
#   87,
#   86,
#   95,
#   68,
#   63,
#   54,
#   47,
#   67,
#   49,
#   66,
#   66,
#   53,
#   53,
#   51,
#   66,
#   64,
#   58,
#   53,
#   53,
#   74,
#   70,
#   55,
#   51,
#   54,
#   53,
#   47,
#   49,
#   55,
#   53,
#   52,
#   55,
#   90,
#   71,
#   86,
#   78,
#   68,
#   73,
#   85,
#   100,
#   77,
#   60,
#   67,
#   76,
#   70,
#   78,
#   56,
#   65,
#   66,
#   79,
#   69,
#   67,
#   69,
#   58,
#   70,
#   79,
#   67,
#   62,
#   74,
#   56,
#   96,
#   88,
#   85,
#   70,
#   85,
#   76,
#   81,
#   99,
#   83,
#   53,
#   80,
#   82,
#   75,
#   90,
#   78,
#   80,
#   88,
#   92,
#   71,
#   78,
#   67,
#   73,
#   91,
#   85,
#   68,
#   88,
#   90,
#   74,
#   84,
#   101,
#   98,
#   78,
#   80,
#   68,
#   76,
#   86,
#   83,
#   79,
#   92,
#   84,
#   67,
#   88,
#   68,
#   78,
#   78,
#   96,
#   88,
#   65,
#   68,
#   79,
#   76,
#   90,
#   90,
#   73,
#   77,
#   76,
#   85,
#   65,
#   106,
#   79,
#   92,
#   80,
#   90,
#   77,
#   89,
#   77,
#   65,
#   54,
#   102,
#   72,
#   83,
#   74,
#   70,
#   65,
#   114,
#   88,
#   74,
#   75,
#   69,
#   98,
#   76,
#   89,
#   83,
#   63,
#   88,
#   88,
#   70,
#   100,
#   103,
#   78,
#   94,
#   75,
#   67,
#   96,
#   97,
#   72,
#   69,
#   64,
#   97,
#   64,
#   77,
#   74,
#   63,
#   68,
#   98,
#   97,
#   87,
#   77,
#   78,
#   74,
#   79,
#   86,
#   75,
#   69,
#   95,
#   84,
#   82,
#   85,
#   95,
#   74,
#   85,
#   95,
#   65,
#   85,
#   90,
#   82,
#   79,
#   79,
#   72,
#   77,
#   86,
#   73,
#   69,
#   67,
#   87,
#   94,
#   91,
#   65,
#   69,
#   76,
#   91,
#   97,
#   95,
#   69,
#   71,
#   83,
#   75,
#   92,
#   88,
#   63,
#   82,
#   83,
#   88,
#   66,
#   91,
#   73,
#   66,
#   76,
#   93,
#   65,
#   86,
#   68,
#   85,
#   68,
#   95,
#   82,
#   102,
#   86,
#   62,
#   79,
#   116,
#   90,
#   93,
#   62,
#   73,
#   80,
#   99,
#   98,
#   101,
#   67,
#   93,
#   81,
#   67,
#   78,
#   74,
#   73,
#   55,
#   79,
#   84,
#   62,
#   92,
#   56,
#   94,
#   83,
#   103,
#   75,
#   103,
#   80,
#   72,
#   66,
#   93,
#   95,
#   97,
#   55,
#   72,
#   78,
#   77,
#   84,
#   101,
#   71,
#   95,
#   86,
#   88,
#   69,
#   68,
#   74,
#   43,
#   91,
#   87,
#   83,
#   85,
#   68,
#   90,
#   83,
#   101,
#   66,
#   96,
#   86,
#   75,
#   64,
#   93,
#   100,
#   85,
#   63,
#   71,
#   86,
#   92,
#   51,
#   96,
#   78,
#   98,
#   83,
#   89,
#   76,
#   80,
#   68,
#   72,
#   83,
#   92,
#   58,
#   93,
#   67,
#   92,
#   67,
#   101,
#   71,
#   91,
#   86,
#   72,
#   87,
#   63,
#   91,
#   105,
#   70,
#   89,
#   67,
#   77,
#   90,
#   74,
#   95,
#   99,
#   79,
#   73,
#   93,
#   67,
#   71,
#   83,
#   89,
#   56,
#   95,
#   71,
#   81,
#   83,
#   95,
#   83,
#   88,
#   88,
#   67,
#   82,
#   69,
#   75,
#   100,
#   67,
#   79,
#   80,
#   81,
#   76,
#   79,
#   70,
#   86,
#   90,
#   66,
#   80,
#   78,
#   76,
#   95,
#   78,
#   82,
#   62,
#   89,
#   88,
#   75,
#   96,
#   97,
#   97,
#   93,
#   85,
#   67,
#   88,
#   78,
#   76,
#   83,
#   61,
#   80,
#   87,
#   71,
#   90,
#   84,
#   69,
#   96,
#   72,
#   85,
#   ...],
#  'Label': [[736, 76, 1970, 'ATL'],
#   [792, 108, 1970, 'BAL'],
#   [786, 87, 1970, 'BOS'],
#   [631, 86, 1970, 'ANA'],
#   [633, 56, 1970, 'CHW'],
#   [806, 84, 1970, 'CHC'],
#   [775, 102, 1970, 'CIN'],
#   [649, 76, 1970, 'CLE'],
#   [666, 79, 1970, 'DET'],
#   [744, 79, 1970, 'HOU'],
#   [611, 65, 1970, 'KCR'],
#   [749, 87, 1970, 'LAD'],
#   [744, 98, 1970, 'MIN'],
#   [613, 65, 1970, 'MIL'],
#   [687, 73, 1970, 'WSN'],
#   [680, 93, 1970, 'NYY'],
#   [695, 83, 1970, 'NYM'],
#   [678, 89, 1970, 'OAK'],
#   [594, 73, 1970, 'PHI'],
#   [729, 89, 1970, 'PIT'],
#   [681, 63, 1970, 'SDP'],
#   [831, 86, 1970, 'SFG'],
#   [744, 76, 1970, 'STL'],
#   [626, 70, 1970, 'TEX'],
#   [643, 82, 1971, 'ATL'],
#   [742, 101, 1971, 'BAL'],
#   [691, 85, 1971, 'BOS'],
#   [511, 76, 1971, 'ANA'],
#   [617, 79, 1971, 'CHW'],
#   [637, 83, 1971, 'CHC'],
#   [586, 79, 1971, 'CIN'],
#   [543, 60, 1971, 'CLE'],
#   [701, 91, 1971, 'DET'],
#   [585, 79, 1971, 'HOU'],
#   [603, 85, 1971, 'KCR'],
#   [663, 89, 1971, 'LAD'],
#   [654, 74, 1971, 'MIN'],
#   [534, 69, 1971, 'MIL'],
#   [622, 71, 1971, 'WSN'],
#   [648, 82, 1971, 'NYY'],
#   [588, 83, 1971, 'NYM'],
#   [691, 101, 1971, 'OAK'],
#   [558, 67, 1971, 'PHI'],
#   [788, 97, 1971, 'PIT'],
#   [486, 61, 1971, 'SDP'],
#   [706, 90, 1971, 'SFG'],
#   [739, 90, 1971, 'STL'],
#   [537, 63, 1971, 'TEX'],
#   [628, 70, 1972, 'ATL'],
#   [519, 80, 1972, 'BAL'],
#   [640, 85, 1972, 'BOS'],
#   [454, 75, 1972, 'ANA'],
#   [566, 87, 1972, 'CHW'],
#   [685, 85, 1972, 'CHC'],
#   [707, 95, 1972, 'CIN'],
#   [472, 72, 1972, 'CLE'],
#   [558, 86, 1972, 'DET'],
#   [708, 84, 1972, 'HOU'],
#   [580, 76, 1972, 'KCR'],
#   [584, 85, 1972, 'LAD'],
#   [537, 77, 1972, 'MIN'],
#   [493, 65, 1972, 'MIL'],
#   [513, 70, 1972, 'WSN'],
#   [557, 79, 1972, 'NYY'],
#   [528, 83, 1972, 'NYM'],
#   [604, 93, 1972, 'OAK'],
#   [503, 59, 1972, 'PHI'],
#   [691, 96, 1972, 'PIT'],
#   [488, 58, 1972, 'SDP'],
#   [662, 69, 1972, 'SFG'],
#   [568, 75, 1972, 'STL'],
#   [461, 54, 1972, 'TEX'],
#   [799, 76, 1973, 'ATL'],
#   [754, 97, 1973, 'BAL'],
#   [738, 89, 1973, 'BOS'],
#   [629, 79, 1973, 'ANA'],
#   [652, 77, 1973, 'CHW'],
#   [614, 77, 1973, 'CHC'],
#   [741, 99, 1973, 'CIN'],
#   [680, 71, 1973, 'CLE'],
#   [642, 85, 1973, 'DET'],
#   [681, 82, 1973, 'HOU'],
#   [755, 88, 1973, 'KCR'],
#   [675, 95, 1973, 'LAD'],
#   [738, 81, 1973, 'MIN'],
#   [708, 74, 1973, 'MIL'],
#   [668, 79, 1973, 'WSN'],
#   [641, 80, 1973, 'NYY'],
#   [608, 82, 1973, 'NYM'],
#   [758, 94, 1973, 'OAK'],
#   [642, 71, 1973, 'PHI'],
#   [704, 80, 1973, 'PIT'],
#   [548, 60, 1973, 'SDP'],
#   [739, 88, 1973, 'SFG'],
#   [643, 81, 1973, 'STL'],
#   [619, 57, 1973, 'TEX'],
#   [661, 88, 1974, 'ATL'],
#   [659, 91, 1974, 'BAL'],
#   [696, 84, 1974, 'BOS'],
#   [618, 68, 1974, 'ANA'],
#   [684, 80, 1974, 'CHW'],
#   [669, 66, 1974, 'CHC'],
#   [776, 98, 1974, 'CIN'],
#   [662, 77, 1974, 'CLE'],
#   [620, 72, 1974, 'DET'],
#   [653, 81, 1974, 'HOU'],
#   [667, 77, 1974, 'KCR'],
#   [798, 102, 1974, 'LAD'],
#   [673, 82, 1974, 'MIN'],
#   [647, 76, 1974, 'MIL'],
#   [662, 79, 1974, 'WSN'],
#   [671, 89, 1974, 'NYY'],
#   [572, 71, 1974, 'NYM'],
#   [689, 90, 1974, 'OAK'],
#   [676, 80, 1974, 'PHI'],
#   [751, 88, 1974, 'PIT'],
#   [541, 60, 1974, 'SDP'],
#   [634, 72, 1974, 'SFG'],
#   [677, 86, 1974, 'STL'],
#   [690, 84, 1974, 'TEX'],
#   [583, 67, 1975, 'ATL'],
#   [682, 90, 1975, 'BAL'],
#   [796, 95, 1975, 'BOS'],
#   [628, 72, 1975, 'ANA'],
#   [655, 75, 1975, 'CHW'],
#   [712, 75, 1975, 'CHC'],
#   [840, 108, 1975, 'CIN'],
#   [688, 79, 1975, 'CLE'],
#   [570, 57, 1975, 'DET'],
#   [664, 64, 1975, 'HOU'],
#   [710, 91, 1975, 'KCR'],
#   [648, 88, 1975, 'LAD'],
#   [724, 76, 1975, 'MIN'],
#   [675, 68, 1975, 'MIL'],
#   [601, 75, 1975, 'WSN'],
#   [681, 83, 1975, 'NYY'],
#   [646, 82, 1975, 'NYM'],
#   [758, 98, 1975, 'OAK'],
#   [735, 86, 1975, 'PHI'],
#   [712, 92, 1975, 'PIT'],
#   [552, 71, 1975, 'SDP'],
#   [659, 80, 1975, 'SFG'],
#   [662, 82, 1975, 'STL'],
#   [714, 79, 1975, 'TEX'],
#   [620, 70, 1976, 'ATL'],
#   [619, 88, 1976, 'BAL'],
#   [716, 83, 1976, 'BOS'],
#   [550, 76, 1976, 'ANA'],
#   [586, 64, 1976, 'CHW'],
#   [611, 75, 1976, 'CHC'],
#   [857, 102, 1976, 'CIN'],
#   [615, 81, 1976, 'CLE'],
#   [609, 74, 1976, 'DET'],
#   [625, 80, 1976, 'HOU'],
#   [713, 90, 1976, 'KCR'],
#   [608, 92, 1976, 'LAD'],
#   [743, 85, 1976, 'MIN'],
#   [570, 66, 1976, 'MIL'],
#   [531, 55, 1976, 'WSN'],
#   [730, 97, 1976, 'NYY'],
#   [615, 86, 1976, 'NYM'],
#   [686, 87, 1976, 'OAK'],
#   [770, 101, 1976, 'PHI'],
#   [708, 92, 1976, 'PIT'],
#   [570, 73, 1976, 'SDP'],
#   [595, 74, 1976, 'SFG'],
#   [629, 72, 1976, 'STL'],
#   [616, 76, 1976, 'TEX'],
#   [678, 61, 1977, 'ATL'],
#   [719, 97, 1977, 'BAL'],
#   [859, 97, 1977, 'BOS'],
#   [675, 74, 1977, 'ANA'],
#   [844, 90, 1977, 'CHW'],
#   [692, 81, 1977, 'CHC'],
#   [802, 88, 1977, 'CIN'],
#   [676, 71, 1977, 'CLE'],
#   [714, 74, 1977, 'DET'],
#   [680, 81, 1977, 'HOU'],
#   [822, 102, 1977, 'KCR'],
#   [769, 98, 1977, 'LAD'],
#   [867, 84, 1977, 'MIN'],
#   [639, 67, 1977, 'MIL'],
#   [665, 75, 1977, 'WSN'],
#   [831, 100, 1977, 'NYY'],
#   [587, 64, 1977, 'NYM'],
#   [605, 63, 1977, 'OAK'],
#   [847, 101, 1977, 'PHI'],
#   [734, 96, 1977, 'PIT'],
#   [692, 69, 1977, 'SDP'],
#   [624, 64, 1977, 'SEA'],
#   [673, 75, 1977, 'SFG'],
#   [737, 83, 1977, 'STL'],
#   [767, 94, 1977, 'TEX'],
#   [605, 54, 1977, 'TOR'],
#   [600, 69, 1978, 'ATL'],
#   [659, 90, 1978, 'BAL'],
#   [796, 99, 1978, 'BOS'],
#   [691, 87, 1978, 'ANA'],
#   [634, 71, 1978, 'CHW'],
#   [664, 79, 1978, 'CHC'],
#   [710, 92, 1978, 'CIN'],
#   [639, 69, 1978, 'CLE'],
#   [714, 86, 1978, 'DET'],
#   [605, 74, 1978, 'HOU'],
#   [743, 92, 1978, 'KCR'],
#   [727, 95, 1978, 'LAD'],
#   [666, 73, 1978, 'MIN'],
#   [804, 93, 1978, 'MIL'],
#   [633, 76, 1978, 'WSN'],
#   [735, 100, 1978, 'NYY'],
#   [607, 66, 1978, 'NYM'],
#   [532, 69, 1978, 'OAK'],
#   [708, 90, 1978, 'PHI'],
#   [684, 88, 1978, 'PIT'],
#   [591, 84, 1978, 'SDP'],
#   [614, 56, 1978, 'SEA'],
#   [613, 89, 1978, 'SFG'],
#   [600, 69, 1978, 'STL'],
#   [692, 87, 1978, 'TEX'],
#   [590, 59, 1978, 'TOR'],
#   [669, 66, 1979, 'ATL'],
#   [757, 102, 1979, 'BAL'],
#   [841, 91, 1979, 'BOS'],
#   [866, 88, 1979, 'ANA'],
#   [730, 73, 1979, 'CHW'],
#   [706, 80, 1979, 'CHC'],
#   [731, 90, 1979, 'CIN'],
#   [760, 81, 1979, 'CLE'],
#   [770, 85, 1979, 'DET'],
#   [583, 89, 1979, 'HOU'],
#   [851, 85, 1979, 'KCR'],
#   [739, 79, 1979, 'LAD'],
#   [764, 82, 1979, 'MIN'],
#   [807, 95, 1979, 'MIL'],
#   [701, 95, 1979, 'WSN'],
#   [734, 89, 1979, 'NYY'],
#   [593, 63, 1979, 'NYM'],
#   [573, 54, 1979, 'OAK'],
#   [683, 84, 1979, 'PHI'],
#   [775, 98, 1979, 'PIT'],
#   [603, 68, 1979, 'SDP'],
#   [711, 67, 1979, 'SEA'],
#   [672, 71, 1979, 'SFG'],
#   [731, 86, 1979, 'STL'],
#   [750, 83, 1979, 'TEX'],
#   [613, 53, 1979, 'TOR'],
#   [630, 81, 1980, 'ATL'],
#   [805, 100, 1980, 'BAL'],
#   [757, 83, 1980, 'BOS'],
#   [698, 65, 1980, 'ANA'],
#   [587, 70, 1980, 'CHW'],
#   [614, 64, 1980, 'CHC'],
#   [707, 89, 1980, 'CIN'],
#   [738, 79, 1980, 'CLE'],
#   [830, 84, 1980, 'DET'],
#   [637, 93, 1980, 'HOU'],
#   [809, 97, 1980, 'KCR'],
#   [663, 92, 1980, 'LAD'],
#   [670, 77, 1980, 'MIN'],
#   [811, 86, 1980, 'MIL'],
#   [694, 90, 1980, 'WSN'],
#   [820, 103, 1980, 'NYY'],
#   [611, 67, 1980, 'NYM'],
#   [686, 83, 1980, 'OAK'],
#   [728, 91, 1980, 'PHI'],
#   [666, 83, 1980, 'PIT'],
#   [591, 73, 1980, 'SDP'],
#   [610, 59, 1980, 'SEA'],
#   [573, 75, 1980, 'SFG'],
#   [738, 74, 1980, 'STL'],
#   [756, 76, 1980, 'TEX'],
#   [624, 67, 1980, 'TOR'],
#   [395, 50, 1981, 'ATL'],
#   [429, 59, 1981, 'BAL'],
#   [519, 59, 1981, 'BOS'],
#   [476, 51, 1981, 'ANA'],
#   [476, 54, 1981, 'CHW'],
#   [370, 38, 1981, 'CHC'],
#   [464, 66, 1981, 'CIN'],
#   [431, 52, 1981, 'CLE'],
#   [427, 60, 1981, 'DET'],
#   [394, 61, 1981, 'HOU'],
#   [397, 50, 1981, 'KCR'],
#   [450, 63, 1981, 'LAD'],
#   [378, 41, 1981, 'MIN'],
#   [493, 62, 1981, 'MIL'],
#   [443, 60, 1981, 'WSN'],
#   [421, 59, 1981, 'NYY'],
#   [348, 41, 1981, 'NYM'],
#   [458, 64, 1981, 'OAK'],
#   [491, 59, 1981, 'PHI'],
#   [407, 46, 1981, 'PIT'],
#   [382, 41, 1981, 'SDP'],
#   [426, 44, 1981, 'SEA'],
#   [427, 56, 1981, 'SFG'],
#   [464, 59, 1981, 'STL'],
#   [452, 57, 1981, 'TEX'],
#   [329, 37, 1981, 'TOR'],
#   [739, 89, 1982, 'ATL'],
#   [774, 94, 1982, 'BAL'],
#   [753, 89, 1982, 'BOS'],
#   [814, 93, 1982, 'ANA'],
#   [786, 87, 1982, 'CHW'],
#   [676, 73, 1982, 'CHC'],
#   [545, 61, 1982, 'CIN'],
#   [683, 78, 1982, 'CLE'],
#   [729, 83, 1982, 'DET'],
#   [569, 77, 1982, 'HOU'],
#   [784, 90, 1982, 'KCR'],
#   [691, 88, 1982, 'LAD'],
#   [657, 60, 1982, 'MIN'],
#   [891, 95, 1982, 'MIL'],
#   [697, 86, 1982, 'WSN'],
#   [709, 79, 1982, 'NYY'],
#   [609, 65, 1982, 'NYM'],
#   [691, 68, 1982, 'OAK'],
#   [664, 89, 1982, 'PHI'],
#   [724, 84, 1982, 'PIT'],
#   [675, 81, 1982, 'SDP'],
#   [651, 76, 1982, 'SEA'],
#   [673, 87, 1982, 'SFG'],
#   [685, 92, 1982, 'STL'],
#   [590, 64, 1982, 'TEX'],
#   [651, 78, 1982, 'TOR'],
#   [746, 88, 1983, 'ATL'],
#   [799, 98, 1983, 'BAL'],
#   [724, 78, 1983, 'BOS'],
#   [722, 70, 1983, 'ANA'],
#   [800, 99, 1983, 'CHW'],
#   [701, 71, 1983, 'CHC'],
#   [623, 74, 1983, 'CIN'],
#   [704, 70, 1983, 'CLE'],
#   [789, 92, 1983, 'DET'],
#   [643, 85, 1983, 'HOU'],
#   [696, 79, 1983, 'KCR'],
#   [654, 91, 1983, 'LAD'],
#   [709, 70, 1983, 'MIN'],
#   [764, 87, 1983, 'MIL'],
#   [677, 82, 1983, 'WSN'],
#   [770, 91, 1983, 'NYY'],
#   [575, 68, 1983, 'NYM'],
#   [708, 74, 1983, 'OAK'],
#   [696, 90, 1983, 'PHI'],
#   [659, 84, 1983, 'PIT'],
#   [653, 81, 1983, 'SDP'],
#   [558, 60, 1983, 'SEA'],
#   [687, 79, 1983, 'SFG'],
#   [679, 79, 1983, 'STL'],
#   [639, 77, 1983, 'TEX'],
#   [795, 89, 1983, 'TOR'],
#   [632, 80, 1984, 'ATL'],
#   [681, 85, 1984, 'BAL'],
#   [810, 86, 1984, 'BOS'],
#   [696, 81, 1984, 'ANA'],
#   [679, 74, 1984, 'CHW'],
#   [762, 96, 1984, 'CHC'],
#   [627, 70, 1984, 'CIN'],
#   [761, 75, 1984, 'CLE'],
#   [829, 104, 1984, 'DET'],
#   [693, 80, 1984, 'HOU'],
#   [673, 84, 1984, 'KCR'],
#   [580, 79, 1984, 'LAD'],
#   [673, 81, 1984, 'MIN'],
#   [641, 67, 1984, 'MIL'],
#   [593, 78, 1984, 'WSN'],
#   [758, 87, 1984, 'NYY'],
#   [652, 90, 1984, 'NYM'],
#   [738, 77, 1984, 'OAK'],
#   [720, 81, 1984, 'PHI'],
#   [615, 75, 1984, 'PIT'],
#   [686, 92, 1984, 'SDP'],
#   [682, 74, 1984, 'SEA'],
#   [682, 66, 1984, 'SFG'],
#   [652, 84, 1984, 'STL'],
#   [656, 69, 1984, 'TEX'],
#   [750, 89, 1984, 'TOR'],
#   [632, 66, 1985, 'ATL'],
#   [818, 83, 1985, 'BAL'],
#   [800, 81, 1985, 'BOS'],
#   [732, 90, 1985, 'ANA'],
#   [736, 85, 1985, 'CHW'],
#   [686, 77, 1985, 'CHC'],
#   [677, 89, 1985, 'CIN'],
#   [729, 60, 1985, 'CLE'],
#   [729, 84, 1985, 'DET'],
#   [706, 83, 1985, 'HOU'],
#   [687, 91, 1985, 'KCR'],
#   [682, 95, 1985, 'LAD'],
#   [705, 77, 1985, 'MIN'],
#   [690, 71, 1985, 'MIL'],
#   [633, 84, 1985, 'WSN'],
#   [839, 97, 1985, 'NYY'],
#   [695, 98, 1985, 'NYM'],
#   [757, 77, 1985, 'OAK'],
#   [667, 75, 1985, 'PHI'],
#   [568, 57, 1985, 'PIT'],
#   [650, 83, 1985, 'SDP'],
#   [719, 74, 1985, 'SEA'],
#   [556, 62, 1985, 'SFG'],
#   [747, 101, 1985, 'STL'],
#   [617, 62, 1985, 'TEX'],
#   [759, 99, 1985, 'TOR'],
#   [615, 72, 1986, 'ATL'],
#   [708, 73, 1986, 'BAL'],
#   [794, 95, 1986, 'BOS'],
#   [786, 92, 1986, 'ANA'],
#   [644, 72, 1986, 'CHW'],
#   [680, 70, 1986, 'CHC'],
#   [732, 86, 1986, 'CIN'],
#   [831, 84, 1986, 'CLE'],
#   [798, 87, 1986, 'DET'],
#   [654, 96, 1986, 'HOU'],
#   [654, 76, 1986, 'KCR'],
#   [638, 73, 1986, 'LAD'],
#   [741, 71, 1986, 'MIN'],
#   [667, 77, 1986, 'MIL'],
#   [637, 78, 1986, 'WSN'],
#   [797, 90, 1986, 'NYY'],
#   [783, 108, 1986, 'NYM'],
#   [731, 76, 1986, 'OAK'],
#   [739, 86, 1986, 'PHI'],
#   [663, 64, 1986, 'PIT'],
#   [656, 74, 1986, 'SDP'],
#   [718, 67, 1986, 'SEA'],
#   [698, 83, 1986, 'SFG'],
#   [601, 79, 1986, 'STL'],
#   [771, 87, 1986, 'TEX'],
#   [809, 86, 1986, 'TOR'],
#   [747, 69, 1987, 'ATL'],
#   [729, 67, 1987, 'BAL'],
#   [842, 78, 1987, 'BOS'],
#   [770, 75, 1987, 'ANA'],
#   [748, 77, 1987, 'CHW'],
#   [720, 76, 1987, 'CHC'],
#   [783, 84, 1987, 'CIN'],
#   [742, 61, 1987, 'CLE'],
#   [896, 98, 1987, 'DET'],
#   [648, 76, 1987, 'HOU'],
#   [715, 83, 1987, 'KCR'],
#   [635, 73, 1987, 'LAD'],
#   [786, 85, 1987, 'MIN'],
#   [862, 91, 1987, 'MIL'],
#   [741, 91, 1987, 'WSN'],
#   [788, 89, 1987, 'NYY'],
#   [823, 92, 1987, 'NYM'],
#   [806, 81, 1987, 'OAK'],
#   [702, 80, 1987, 'PHI'],
#   [723, 80, 1987, 'PIT'],
#   [668, 65, 1987, 'SDP'],
#   [760, 78, 1987, 'SEA'],
#   [783, 90, 1987, 'SFG'],
#   [798, 95, 1987, 'STL'],
#   [823, 75, 1987, 'TEX'],
#   [845, 96, 1987, 'TOR'],
#   [555, 54, 1988, 'ATL'],
#   [550, 54, 1988, 'BAL'],
#   [813, 89, 1988, 'BOS'],
#   [714, 75, 1988, 'ANA'],
#   [631, 71, 1988, 'CHW'],
#   [660, 77, 1988, 'CHC'],
#   [641, 87, 1988, 'CIN'],
#   [666, 78, 1988, 'CLE'],
#   [703, 88, 1988, 'DET'],
#   [617, 82, 1988, 'HOU'],
#   [704, 84, 1988, 'KCR'],
#   [628, 94, 1988, 'LAD'],
#   [759, 91, 1988, 'MIN'],
#   [682, 87, 1988, 'MIL'],
#   [628, 81, 1988, 'WSN'],
#   [772, 85, 1988, 'NYY'],
#   [703, 100, 1988, 'NYM'],
#   [800, 104, 1988, 'OAK'],
#   [597, 65, 1988, 'PHI'],
#   [651, 85, 1988, 'PIT'],
#   [594, 83, 1988, 'SDP'],
#   [664, 68, 1988, 'SEA'],
#   [670, 83, 1988, 'SFG'],
#   [578, 76, 1988, 'STL'],
#   [637, 70, 1988, 'TEX'],
#   [763, 87, 1988, 'TOR'],
#   [584, 63, 1989, 'ATL'],
#   [708, 87, 1989, 'BAL'],
#   [774, 83, 1989, 'BOS'],
#   [669, 91, 1989, 'ANA'],
#   [693, 69, 1989, 'CHW'],
#   [702, 93, 1989, 'CHC'],
#   [632, 75, 1989, 'CIN'],
#   [604, 73, 1989, 'CLE'],
#   [617, 59, 1989, 'DET'],
#   [647, 86, 1989, 'HOU'],
#   [690, 92, 1989, 'KCR'],
#   [554, 77, 1989, 'LAD'],
#   [740, 80, 1989, 'MIN'],
#   [707, 81, 1989, 'MIL'],
#   [632, 81, 1989, 'WSN'],
#   [698, 74, 1989, 'NYY'],
#   [683, 87, 1989, 'NYM'],
#   [712, 99, 1989, 'OAK'],
#   [629, 67, 1989, 'PHI'],
#   [637, 74, 1989, 'PIT'],
#   [642, 89, 1989, 'SDP'],
#   [694, 73, 1989, 'SEA'],
#   [699, 92, 1989, 'SFG'],
#   [632, 86, 1989, 'STL'],
#   [695, 83, 1989, 'TEX'],
#   [731, 89, 1989, 'TOR'],
#   [682, 65, 1990, 'ATL'],
#   [669, 76, 1990, 'BAL'],
#   [699, 88, 1990, 'BOS'],
#   [690, 80, 1990, 'ANA'],
#   [682, 94, 1990, 'CHW'],
#   [690, 77, 1990, 'CHC'],
#   [693, 91, 1990, 'CIN'],
#   [732, 77, 1990, 'CLE'],
#   [750, 79, 1990, 'DET'],
#   [573, 75, 1990, 'HOU'],
#   [707, 75, 1990, 'KCR'],
#   [728, 86, 1990, 'LAD'],
#   [666, 74, 1990, 'MIN'],
#   [732, 74, 1990, 'MIL'],
#   [662, 85, 1990, 'WSN'],
#   [603, 67, 1990, 'NYY'],
#   [775, 91, 1990, 'NYM'],
#   [733, 103, 1990, 'OAK'],
#   [646, 77, 1990, 'PHI'],
#   [733, 95, 1990, 'PIT'],
#   [673, 75, 1990, 'SDP'],
#   [640, 77, 1990, 'SEA'],
#   [719, 85, 1990, 'SFG'],
#   [599, 70, 1990, 'STL'],
#   [676, 83, 1990, 'TEX'],
#   [767, 86, 1990, 'TOR'],
#   [749, 94, 1991, 'ATL'],
#   [686, 67, 1991, 'BAL'],
#   [731, 84, 1991, 'BOS'],
#   [653, 81, 1991, 'ANA'],
#   [758, 87, 1991, 'CHW'],
#   [695, 77, 1991, 'CHC'],
#   [689, 74, 1991, 'CIN'],
#   [576, 57, 1991, 'CLE'],
#   [817, 84, 1991, 'DET'],
#   [605, 65, 1991, 'HOU'],
#   [727, 82, 1991, 'KCR'],
#   [665, 93, 1991, 'LAD'],
#   [776, 95, 1991, 'MIN'],
#   [799, 83, 1991, 'MIL'],
#   [579, 71, 1991, 'WSN'],
#   [674, 71, 1991, 'NYY'],
#   [640, 77, 1991, 'NYM'],
#   [760, 84, 1991, 'OAK'],
#   [629, 78, 1991, 'PHI'],
#   [768, 98, 1991, 'PIT'],
#   [636, 84, 1991, 'SDP'],
#   [702, 83, 1991, 'SEA'],
#   [649, 75, 1991, 'SFG'],
#   [651, 84, 1991, 'STL'],
#   [829, 85, 1991, 'TEX'],
#   [684, 91, 1991, 'TOR'],
#   [682, 98, 1992, 'ATL'],
#   [705, 89, 1992, 'BAL'],
#   [599, 73, 1992, 'BOS'],
#   [579, 72, 1992, 'ANA'],
#   [738, 86, 1992, 'CHW'],
#   [593, 78, 1992, 'CHC'],
#   [660, 90, 1992, 'CIN'],
#   [674, 76, 1992, 'CLE'],
#   [791, 75, 1992, 'DET'],
#   [608, 81, 1992, 'HOU'],
#   [610, 72, 1992, 'KCR'],
#   [548, 63, 1992, 'LAD'],
#   [747, 90, 1992, 'MIN'],
#   [740, 92, 1992, 'MIL'],
#   [648, 87, 1992, 'WSN'],
#   [733, 76, 1992, 'NYY'],
#   [599, 72, 1992, 'NYM'],
#   [745, 96, 1992, 'OAK'],
#   [686, 70, 1992, 'PHI'],
#   [693, 96, 1992, 'PIT'],
#   [617, 82, 1992, 'SDP'],
#   [679, 64, 1992, 'SEA'],
#   [574, 72, 1992, 'SFG'],
#   [631, 83, 1992, 'STL'],
#   [682, 77, 1992, 'TEX'],
#   [780, 96, 1992, 'TOR'],
#   [767, 104, 1993, 'ATL'],
#   [786, 85, 1993, 'BAL'],
#   [686, 80, 1993, 'BOS'],
#   [684, 71, 1993, 'ANA'],
#   [776, 94, 1993, 'CHW'],
#   [738, 84, 1993, 'CHC'],
#   [722, 73, 1993, 'CIN'],
#   [790, 76, 1993, 'CLE'],
#   [758, 67, 1993, 'COL'],
#   [899, 85, 1993, 'DET'],
#   [581, 64, 1993, 'FLA'],
#   [716, 85, 1993, 'HOU'],
#   [675, 84, 1993, 'KCR'],
#   [675, 81, 1993, 'LAD'],
#   [693, 71, 1993, 'MIN'],
#   [733, 69, 1993, 'MIL'],
#   [732, 94, 1993, 'WSN'],
#   [821, 88, 1993, 'NYY'],
#   [672, 59, 1993, 'NYM'],
#   [715, 68, 1993, 'OAK'],
#   [877, 97, 1993, 'PHI'],
#   [707, 75, 1993, 'PIT'],
#   [679, 61, 1993, 'SDP'],
#   [734, 82, 1993, 'SEA'],
#   [808, 103, 1993, 'SFG'],
#   [758, 87, 1993, 'STL'],
#   [835, 86, 1993, 'TEX'],
#   [847, 95, 1993, 'TOR'],
#   [542, 68, 1994, 'ATL'],
#   [589, 63, 1994, 'BAL'],
#   [552, 54, 1994, 'BOS'],
#   [543, 47, 1994, 'ANA'],
#   [633, 67, 1994, 'CHW'],
#   [500, 49, 1994, 'CHC'],
#   [609, 66, 1994, 'CIN'],
#   [679, 66, 1994, 'CLE'],
#   [573, 53, 1994, 'COL'],
#   [652, 53, 1994, 'DET'],
#   [468, 51, 1994, 'FLA'],
#   [602, 66, 1994, 'HOU'],
#   [574, 64, 1994, 'KCR'],
#   [532, 58, 1994, 'LAD'],
#   [594, 53, 1994, 'MIN'],
#   [547, 53, 1994, 'MIL'],
#   [585, 74, 1994, 'WSN'],
#   [670, 70, 1994, 'NYY'],
#   [506, 55, 1994, 'NYM'],
#   [549, 51, 1994, 'OAK'],
#   [521, 54, 1994, 'PHI'],
#   [466, 53, 1994, 'PIT'],
#   [479, 47, 1994, 'SDP'],
#   [569, 49, 1994, 'SEA'],
#   [504, 55, 1994, 'SFG'],
#   [535, 53, 1994, 'STL'],
#   [613, 52, 1994, 'TEX'],
#   [566, 55, 1994, 'TOR'],
#   [645, 90, 1995, 'ATL'],
#   [704, 71, 1995, 'BAL'],
#   [791, 86, 1995, 'BOS'],
#   [801, 78, 1995, 'ANA'],
#   [755, 68, 1995, 'CHW'],
#   [693, 73, 1995, 'CHC'],
#   [747, 85, 1995, 'CIN'],
#   [840, 100, 1995, 'CLE'],
#   [785, 77, 1995, 'COL'],
#   [654, 60, 1995, 'DET'],
#   [673, 67, 1995, 'FLA'],
#   [747, 76, 1995, 'HOU'],
#   [629, 70, 1995, 'KCR'],
#   [634, 78, 1995, 'LAD'],
#   [703, 56, 1995, 'MIN'],
#   [740, 65, 1995, 'MIL'],
#   [621, 66, 1995, 'WSN'],
#   [749, 79, 1995, 'NYY'],
#   [657, 69, 1995, 'NYM'],
#   [730, 67, 1995, 'OAK'],
#   [615, 69, 1995, 'PHI'],
#   [629, 58, 1995, 'PIT'],
#   [668, 70, 1995, 'SDP'],
#   [796, 79, 1995, 'SEA'],
#   [652, 67, 1995, 'SFG'],
#   [563, 62, 1995, 'STL'],
#   [691, 74, 1995, 'TEX'],
#   [642, 56, 1995, 'TOR'],
#   [773, 96, 1996, 'ATL'],
#   [949, 88, 1996, 'BAL'],
#   [928, 85, 1996, 'BOS'],
#   [762, 70, 1996, 'ANA'],
#   [898, 85, 1996, 'CHW'],
#   [772, 76, 1996, 'CHC'],
#   [778, 81, 1996, 'CIN'],
#   [952, 99, 1996, 'CLE'],
#   [961, 83, 1996, 'COL'],
#   [783, 53, 1996, 'DET'],
#   [688, 80, 1996, 'FLA'],
#   [753, 82, 1996, 'HOU'],
#   [746, 75, 1996, 'KCR'],
#   [703, 90, 1996, 'LAD'],
#   [877, 78, 1996, 'MIN'],
#   [894, 80, 1996, 'MIL'],
#   [741, 88, 1996, 'WSN'],
#   [871, 92, 1996, 'NYY'],
#   [746, 71, 1996, 'NYM'],
#   [861, 78, 1996, 'OAK'],
#   [650, 67, 1996, 'PHI'],
#   [776, 73, 1996, 'PIT'],
#   [771, 91, 1996, 'SDP'],
#   [993, 85, 1996, 'SEA'],
#   [752, 68, 1996, 'SFG'],
#   [759, 88, 1996, 'STL'],
#   [928, 90, 1996, 'TEX'],
#   [766, 74, 1996, 'TOR'],
#   [829, 84, 1997, 'ANA'],
#   [791, 101, 1997, 'ATL'],
#   [812, 98, 1997, 'BAL'],
#   [851, 78, 1997, 'BOS'],
#   [779, 80, 1997, 'CHW'],
#   [687, 68, 1997, 'CHC'],
#   [651, 76, 1997, 'CIN'],
#   [868, 86, 1997, 'CLE'],
#   [923, 83, 1997, 'COL'],
#   [784, 79, 1997, 'DET'],
#   [740, 92, 1997, 'FLA'],
#   [777, 84, 1997, 'HOU'],
#   [747, 67, 1997, 'KCR'],
#   [742, 88, 1997, 'LAD'],
#   [772, 68, 1997, 'MIN'],
#   [681, 78, 1997, 'MIL'],
#   [691, 78, 1997, 'WSN'],
#   [891, 96, 1997, 'NYY'],
#   [777, 88, 1997, 'NYM'],
#   [764, 65, 1997, 'OAK'],
#   [668, 68, 1997, 'PHI'],
#   [725, 79, 1997, 'PIT'],
#   [795, 76, 1997, 'SDP'],
#   [925, 90, 1997, 'SEA'],
#   [784, 90, 1997, 'SFG'],
#   [689, 73, 1997, 'STL'],
#   [807, 77, 1997, 'TEX'],
#   [654, 76, 1997, 'TOR'],
#   [787, 85, 1998, 'ANA'],
#   [665, 65, 1998, 'ARI'],
#   [826, 106, 1998, 'ATL'],
#   [817, 79, 1998, 'BAL'],
#   [876, 92, 1998, 'BOS'],
#   [861, 80, 1998, 'CHW'],
#   [831, 90, 1998, 'CHC'],
#   [750, 77, 1998, 'CIN'],
#   [850, 89, 1998, 'CLE'],
#   [826, 77, 1998, 'COL'],
#   [722, 65, 1998, 'DET'],
#   [667, 54, 1998, 'FLA'],
#   [874, 102, 1998, 'HOU'],
#   [714, 72, 1998, 'KCR'],
#   [669, 83, 1998, 'LAD'],
#   [707, 74, 1998, 'MIL'],
#   [734, 70, 1998, 'MIN'],
#   [644, 65, 1998, 'WSN'],
#   [965, 114, 1998, 'NYY'],
#   [706, 88, 1998, 'NYM'],
#   [804, 74, 1998, 'OAK'],
#   [713, 75, 1998, 'PHI'],
#   [650, 69, 1998, 'PIT'],
#   [749, 98, 1998, 'SDP'],
#   [859, 76, 1998, 'SEA'],
#   [845, 89, 1998, 'SFG'],
#   [810, 83, 1998, 'STL'],
#   [620, 63, 1998, 'TBD'],
#   [940, 88, 1998, 'TEX'],
#   [816, 88, 1998, 'TOR'],
#   [711, 70, 1999, 'ANA'],
#   [908, 100, 1999, 'ARI'],
#   [840, 103, 1999, 'ATL'],
#   [851, 78, 1999, 'BAL'],
#   [836, 94, 1999, 'BOS'],
#   [777, 75, 1999, 'CHW'],
#   [747, 67, 1999, 'CHC'],
#   [865, 96, 1999, 'CIN'],
#   [1009, 97, 1999, 'CLE'],
#   [906, 72, 1999, 'COL'],
#   [747, 69, 1999, 'DET'],
#   [691, 64, 1999, 'FLA'],
#   [823, 97, 1999, 'HOU'],
#   [856, 64, 1999, 'KCR'],
#   [793, 77, 1999, 'LAD'],
#   [815, 74, 1999, 'MIL'],
#   [686, 63, 1999, 'MIN'],
#   [718, 68, 1999, 'WSN'],
#   [900, 98, 1999, 'NYY'],
#   [853, 97, 1999, 'NYM'],
#   [893, 87, 1999, 'OAK'],
#   [841, 77, 1999, 'PHI'],
#   [775, 78, 1999, 'PIT'],
#   [710, 74, 1999, 'SDP'],
#   [859, 79, 1999, 'SEA'],
#   [872, 86, 1999, 'SFG'],
#   [809, 75, 1999, 'STL'],
#   [772, 69, 1999, 'TBD'],
#   [945, 95, 1999, 'TEX'],
#   [883, 84, 1999, 'TOR'],
#   [864, 82, 2000, 'ANA'],
#   [792, 85, 2000, 'ARI'],
#   [810, 95, 2000, 'ATL'],
#   [794, 74, 2000, 'BAL'],
#   [792, 85, 2000, 'BOS'],
#   [978, 95, 2000, 'CHW'],
#   [764, 65, 2000, 'CHC'],
#   [825, 85, 2000, 'CIN'],
#   [950, 90, 2000, 'CLE'],
#   [968, 82, 2000, 'COL'],
#   [823, 79, 2000, 'DET'],
#   [731, 79, 2000, 'FLA'],
#   [938, 72, 2000, 'HOU'],
#   [879, 77, 2000, 'KCR'],
#   [798, 86, 2000, 'LAD'],
#   [740, 73, 2000, 'MIL'],
#   [748, 69, 2000, 'MIN'],
#   [738, 67, 2000, 'WSN'],
#   [871, 87, 2000, 'NYY'],
#   [807, 94, 2000, 'NYM'],
#   [947, 91, 2000, 'OAK'],
#   [708, 65, 2000, 'PHI'],
#   [793, 69, 2000, 'PIT'],
#   [752, 76, 2000, 'SDP'],
#   [907, 91, 2000, 'SEA'],
#   [925, 97, 2000, 'SFG'],
#   [887, 95, 2000, 'STL'],
#   [733, 69, 2000, 'TBD'],
#   [848, 71, 2000, 'TEX'],
#   [861, 83, 2000, 'TOR'],
#   [691, 75, 2001, 'ANA'],
#   [818, 92, 2001, 'ARI'],
#   [729, 88, 2001, 'ATL'],
#   [687, 63, 2001, 'BAL'],
#   [772, 82, 2001, 'BOS'],
#   [798, 83, 2001, 'CHW'],
#   [777, 88, 2001, 'CHC'],
#   [735, 66, 2001, 'CIN'],
#   [897, 91, 2001, 'CLE'],
#   [923, 73, 2001, 'COL'],
#   [724, 66, 2001, 'DET'],
#   [742, 76, 2001, 'FLA'],
#   [847, 93, 2001, 'HOU'],
#   [729, 65, 2001, 'KCR'],
#   [758, 86, 2001, 'LAD'],
#   [740, 68, 2001, 'MIL'],
#   [771, 85, 2001, 'MIN'],
#   [670, 68, 2001, 'WSN'],
#   [804, 95, 2001, 'NYY'],
#   [642, 82, 2001, 'NYM'],
#   [884, 102, 2001, 'OAK'],
#   [746, 86, 2001, 'PHI'],
#   [657, 62, 2001, 'PIT'],
#   [789, 79, 2001, 'SDP'],
#   [927, 116, 2001, 'SEA'],
#   [799, 90, 2001, 'SFG'],
#   [814, 93, 2001, 'STL'],
#   [672, 62, 2001, 'TBD'],
#   [890, 73, 2001, 'TEX'],
#   [767, 80, 2001, 'TOR'],
#   [851, 99, 2002, 'ANA'],
#   [819, 98, 2002, 'ARI'],
#   [708, 101, 2002, 'ATL'],
#   [667, 67, 2002, 'BAL'],
#   [859, 93, 2002, 'BOS'],
#   [856, 81, 2002, 'CHW'],
#   [706, 67, 2002, 'CHC'],
#   [709, 78, 2002, 'CIN'],
#   [739, 74, 2002, 'CLE'],
#   [778, 73, 2002, 'COL'],
#   [575, 55, 2002, 'DET'],
#   [699, 79, 2002, 'FLA'],
#   [749, 84, 2002, 'HOU'],
#   [737, 62, 2002, 'KCR'],
#   [713, 92, 2002, 'LAD'],
#   [627, 56, 2002, 'MIL'],
#   [768, 94, 2002, 'MIN'],
#   [735, 83, 2002, 'WSN'],
#   [897, 103, 2002, 'NYY'],
#   [690, 75, 2002, 'NYM'],
#   [800, 103, 2002, 'OAK'],
#   [710, 80, 2002, 'PHI'],
#   [641, 72, 2002, 'PIT'],
#   [662, 66, 2002, 'SDP'],
#   [814, 93, 2002, 'SEA'],
#   [783, 95, 2002, 'SFG'],
#   [787, 97, 2002, 'STL'],
#   [673, 55, 2002, 'TBD'],
#   [843, 72, 2002, 'TEX'],
#   [813, 78, 2002, 'TOR'],
#   [736, 77, 2003, 'ANA'],
#   [717, 84, 2003, 'ARI'],
#   [907, 101, 2003, 'ATL'],
#   [743, 71, 2003, 'BAL'],
#   [961, 95, 2003, 'BOS'],
#   [791, 86, 2003, 'CHW'],
#   [724, 88, 2003, 'CHC'],
#   [694, 69, 2003, 'CIN'],
#   [699, 68, 2003, 'CLE'],
#   [853, 74, 2003, 'COL'],
#   [591, 43, 2003, 'DET'],
#   [751, 91, 2003, 'FLA'],
#   [805, 87, 2003, 'HOU'],
#   [836, 83, 2003, 'KCR'],
#   [574, 85, 2003, 'LAD'],
#   [714, 68, 2003, 'MIL'],
#   [801, 90, 2003, 'MIN'],
#   [711, 83, 2003, 'WSN'],
#   [877, 101, 2003, 'NYY'],
#   [642, 66, 2003, 'NYM'],
#   [768, 96, 2003, 'OAK'],
#   [791, 86, 2003, 'PHI'],
#   [753, 75, 2003, 'PIT'],
#   [678, 64, 2003, 'SDP'],
#   [795, 93, 2003, 'SEA'],
#   [755, 100, 2003, 'SFG'],
#   [876, 85, 2003, 'STL'],
#   [715, 63, 2003, 'TBD'],
#   [826, 71, 2003, 'TEX'],
#   [894, 86, 2003, 'TOR'],
#   [836, 92, 2004, 'ANA'],
#   [615, 51, 2004, 'ARI'],
#   [803, 96, 2004, 'ATL'],
#   [842, 78, 2004, 'BAL'],
#   [949, 98, 2004, 'BOS'],
#   [865, 83, 2004, 'CHW'],
#   [789, 89, 2004, 'CHC'],
#   [750, 76, 2004, 'CIN'],
#   [858, 80, 2004, 'CLE'],
#   [833, 68, 2004, 'COL'],
#   [827, 72, 2004, 'DET'],
#   [718, 83, 2004, 'FLA'],
#   [803, 92, 2004, 'HOU'],
#   [720, 58, 2004, 'KCR'],
#   [761, 93, 2004, 'LAD'],
#   [634, 67, 2004, 'MIL'],
#   [780, 92, 2004, 'MIN'],
#   [635, 67, 2004, 'WSN'],
#   [897, 101, 2004, 'NYY'],
#   [684, 71, 2004, 'NYM'],
#   [793, 91, 2004, 'OAK'],
#   [840, 86, 2004, 'PHI'],
#   [680, 72, 2004, 'PIT'],
#   [768, 87, 2004, 'SDP'],
#   [698, 63, 2004, 'SEA'],
#   [850, 91, 2004, 'SFG'],
#   [855, 105, 2004, 'STL'],
#   [714, 70, 2004, 'TBD'],
#   [860, 89, 2004, 'TEX'],
#   [719, 67, 2004, 'TOR'],
#   [696, 77, 2005, 'ARI'],
#   [769, 90, 2005, 'ATL'],
#   [729, 74, 2005, 'BAL'],
#   [910, 95, 2005, 'BOS'],
#   [741, 99, 2005, 'CHW'],
#   [703, 79, 2005, 'CHC'],
#   [820, 73, 2005, 'CIN'],
#   [790, 93, 2005, 'CLE'],
#   [740, 67, 2005, 'COL'],
#   [723, 71, 2005, 'DET'],
#   [717, 83, 2005, 'FLA'],
#   [693, 89, 2005, 'HOU'],
#   [701, 56, 2005, 'KCR'],
#   [761, 95, 2005, 'ANA'],
#   [685, 71, 2005, 'LAD'],
#   [726, 81, 2005, 'MIL'],
#   [688, 83, 2005, 'MIN'],
#   [886, 95, 2005, 'NYY'],
#   [722, 83, 2005, 'NYM'],
#   [772, 88, 2005, 'OAK'],
#   [807, 88, 2005, 'PHI'],
#   [680, 67, 2005, 'PIT'],
#   [684, 82, 2005, 'SDP'],
#   [699, 69, 2005, 'SEA'],
#   [649, 75, 2005, 'SFG'],
#   [805, 100, 2005, 'STL'],
#   [750, 67, 2005, 'TBD'],
#   [865, 79, 2005, 'TEX'],
#   [775, 80, 2005, 'TOR'],
#   [639, 81, 2005, 'WSN'],
#   [773, 76, 2006, 'ARI'],
#   [849, 79, 2006, 'ATL'],
#   [768, 70, 2006, 'BAL'],
#   [820, 86, 2006, 'BOS'],
#   [868, 90, 2006, 'CHW'],
#   [716, 66, 2006, 'CHC'],
#   [749, 80, 2006, 'CIN'],
#   [870, 78, 2006, 'CLE'],
#   [813, 76, 2006, 'COL'],
#   [822, 95, 2006, 'DET'],
#   [758, 78, 2006, 'FLA'],
#   [735, 82, 2006, 'HOU'],
#   [757, 62, 2006, 'KCR'],
#   [766, 89, 2006, 'ANA'],
#   [820, 88, 2006, 'LAD'],
#   [730, 75, 2006, 'MIL'],
#   [801, 96, 2006, 'MIN'],
#   [930, 97, 2006, 'NYY'],
#   [834, 97, 2006, 'NYM'],
#   [771, 93, 2006, 'OAK'],
#   [865, 85, 2006, 'PHI'],
#   [691, 67, 2006, 'PIT'],
#   [731, 88, 2006, 'SDP'],
#   [756, 78, 2006, 'SEA'],
#   [746, 76, 2006, 'SFG'],
#   [781, 83, 2006, 'STL'],
#   [689, 61, 2006, 'TBD'],
#   [835, 80, 2006, 'TEX'],
#   [809, 87, 2006, 'TOR'],
#   [746, 71, 2006, 'WSN'],
#   [712, 90, 2007, 'ARI'],
#   [810, 84, 2007, 'ATL'],
#   [756, 69, 2007, 'BAL'],
#   [867, 96, 2007, 'BOS'],
#   [693, 72, 2007, 'CHW'],
#   [752, 85, 2007, 'CHC'],
#   ...]}

# %%
df = pd.read_csv('runsPlotData.csv')
runsData = df.loc[:, ["R", "W", "yearID", "franchID"]]
# Format the data to send as json
labelDict = {"Runs": runsData.R.values.tolist(), "Wins": runsData.W.values.tolist(), "Year": runsData.yearID.values.tolist(), "Franchise": runsData.franchID.values.tolist()} 
labelDF = pd.DataFrame(labelDict)
Label = labelDF.from_dict(labelDict)

# %%
Label
# Out:
#       Runs  Wins  Year Franchise
# 0      736    76  1970       ATL
# 1      792   108  1970       BAL
# 2      786    87  1970       BOS
# 3      631    86  1970       ANA
# 4      633    56  1970       CHW
# 5      806    84  1970       CHC
# 6      775   102  1970       CIN
# 7      649    76  1970       CLE
# 8      666    79  1970       DET
# 9      744    79  1970       HOU
# 10     611    65  1970       KCR
# 11     749    87  1970       LAD
# 12     744    98  1970       MIN
# 13     613    65  1970       MIL
# 14     687    73  1970       WSN
# 15     680    93  1970       NYY
# 16     695    83  1970       NYM
# 17     678    89  1970       OAK
# 18     594    73  1970       PHI
# 19     729    89  1970       PIT
# 20     681    63  1970       SDP
# 21     831    86  1970       SFG
# 22     744    76  1970       STL
# 23     626    70  1970       TEX
# 24     643    82  1971       ATL
# 25     742   101  1971       BAL
# 26     691    85  1971       BOS
# 27     511    76  1971       ANA
# 28     617    79  1971       CHW
# 29     637    83  1971       CHC
# ...    ...   ...   ...       ...
# 1294   812    93  2017       ARI
# 1295   732    72  2017       ATL
# 1296   743    75  2017       BAL
# 1297   785    93  2017       BOS
# 1298   706    67  2017       CHW
# 1299   822    92  2017       CHC
# 1300   753    68  2017       CIN
# 1301   818   102  2017       CLE
# 1302   824    87  2017       COL
# 1303   735    64  2017       DET
# 1304   896   101  2017       HOU
# 1305   702    80  2017       KCR
# 1306   710    80  2017       ANA
# 1307   770   104  2017       LAD
# 1308   778    77  2017       FLA
# 1309   732    86  2017       MIL
# 1310   815    85  2017       MIN
# 1311   858    91  2017       NYY
# 1312   735    70  2017       NYM
# 1313   739    75  2017       OAK
# 1314   690    66  2017       PHI
# 1315   668    75  2017       PIT
# 1316   604    71  2017       SDP
# 1317   750    78  2017       SEA
# 1318   639    64  2017       SFG
# 1319   761    83  2017       STL
# 1320   694    80  2017       TBD
# 1321   799    78  2017       TEX
# 1322   693    76  2017       TOR
# 1323   819    97  2017       WSN
#
# [1324 rows x 4 columns]

# %%
for rows in runsData:
        data = {
        "Runs": runsData.R.values.tolist(), 
        "Wins": runsData.W.values.tolist(),
        "Label": Label.values.tolist()
        }
# Out:
#   File "<ipython-input-7-1220d1d9e0a2>", line 3
#     "Runs": ("Runs" : runsData.R.values.tolist()),
#                     ^
# SyntaxError: invalid syntax

# %%
data
# Out:
# {'Runs': [736,
#   792,
#   786,
#   631,
#   633,
#   806,
#   775,
#   649,
#   666,
#   744,
#   611,
#   749,
#   744,
#   613,
#   687,
#   680,
#   695,
#   678,
#   594,
#   729,
#   681,
#   831,
#   744,
#   626,
#   643,
#   742,
#   691,
#   511,
#   617,
#   637,
#   586,
#   543,
#   701,
#   585,
#   603,
#   663,
#   654,
#   534,
#   622,
#   648,
#   588,
#   691,
#   558,
#   788,
#   486,
#   706,
#   739,
#   537,
#   628,
#   519,
#   640,
#   454,
#   566,
#   685,
#   707,
#   472,
#   558,
#   708,
#   580,
#   584,
#   537,
#   493,
#   513,
#   557,
#   528,
#   604,
#   503,
#   691,
#   488,
#   662,
#   568,
#   461,
#   799,
#   754,
#   738,
#   629,
#   652,
#   614,
#   741,
#   680,
#   642,
#   681,
#   755,
#   675,
#   738,
#   708,
#   668,
#   641,
#   608,
#   758,
#   642,
#   704,
#   548,
#   739,
#   643,
#   619,
#   661,
#   659,
#   696,
#   618,
#   684,
#   669,
#   776,
#   662,
#   620,
#   653,
#   667,
#   798,
#   673,
#   647,
#   662,
#   671,
#   572,
#   689,
#   676,
#   751,
#   541,
#   634,
#   677,
#   690,
#   583,
#   682,
#   796,
#   628,
#   655,
#   712,
#   840,
#   688,
#   570,
#   664,
#   710,
#   648,
#   724,
#   675,
#   601,
#   681,
#   646,
#   758,
#   735,
#   712,
#   552,
#   659,
#   662,
#   714,
#   620,
#   619,
#   716,
#   550,
#   586,
#   611,
#   857,
#   615,
#   609,
#   625,
#   713,
#   608,
#   743,
#   570,
#   531,
#   730,
#   615,
#   686,
#   770,
#   708,
#   570,
#   595,
#   629,
#   616,
#   678,
#   719,
#   859,
#   675,
#   844,
#   692,
#   802,
#   676,
#   714,
#   680,
#   822,
#   769,
#   867,
#   639,
#   665,
#   831,
#   587,
#   605,
#   847,
#   734,
#   692,
#   624,
#   673,
#   737,
#   767,
#   605,
#   600,
#   659,
#   796,
#   691,
#   634,
#   664,
#   710,
#   639,
#   714,
#   605,
#   743,
#   727,
#   666,
#   804,
#   633,
#   735,
#   607,
#   532,
#   708,
#   684,
#   591,
#   614,
#   613,
#   600,
#   692,
#   590,
#   669,
#   757,
#   841,
#   866,
#   730,
#   706,
#   731,
#   760,
#   770,
#   583,
#   851,
#   739,
#   764,
#   807,
#   701,
#   734,
#   593,
#   573,
#   683,
#   775,
#   603,
#   711,
#   672,
#   731,
#   750,
#   613,
#   630,
#   805,
#   757,
#   698,
#   587,
#   614,
#   707,
#   738,
#   830,
#   637,
#   809,
#   663,
#   670,
#   811,
#   694,
#   820,
#   611,
#   686,
#   728,
#   666,
#   591,
#   610,
#   573,
#   738,
#   756,
#   624,
#   395,
#   429,
#   519,
#   476,
#   476,
#   370,
#   464,
#   431,
#   427,
#   394,
#   397,
#   450,
#   378,
#   493,
#   443,
#   421,
#   348,
#   458,
#   491,
#   407,
#   382,
#   426,
#   427,
#   464,
#   452,
#   329,
#   739,
#   774,
#   753,
#   814,
#   786,
#   676,
#   545,
#   683,
#   729,
#   569,
#   784,
#   691,
#   657,
#   891,
#   697,
#   709,
#   609,
#   691,
#   664,
#   724,
#   675,
#   651,
#   673,
#   685,
#   590,
#   651,
#   746,
#   799,
#   724,
#   722,
#   800,
#   701,
#   623,
#   704,
#   789,
#   643,
#   696,
#   654,
#   709,
#   764,
#   677,
#   770,
#   575,
#   708,
#   696,
#   659,
#   653,
#   558,
#   687,
#   679,
#   639,
#   795,
#   632,
#   681,
#   810,
#   696,
#   679,
#   762,
#   627,
#   761,
#   829,
#   693,
#   673,
#   580,
#   673,
#   641,
#   593,
#   758,
#   652,
#   738,
#   720,
#   615,
#   686,
#   682,
#   682,
#   652,
#   656,
#   750,
#   632,
#   818,
#   800,
#   732,
#   736,
#   686,
#   677,
#   729,
#   729,
#   706,
#   687,
#   682,
#   705,
#   690,
#   633,
#   839,
#   695,
#   757,
#   667,
#   568,
#   650,
#   719,
#   556,
#   747,
#   617,
#   759,
#   615,
#   708,
#   794,
#   786,
#   644,
#   680,
#   732,
#   831,
#   798,
#   654,
#   654,
#   638,
#   741,
#   667,
#   637,
#   797,
#   783,
#   731,
#   739,
#   663,
#   656,
#   718,
#   698,
#   601,
#   771,
#   809,
#   747,
#   729,
#   842,
#   770,
#   748,
#   720,
#   783,
#   742,
#   896,
#   648,
#   715,
#   635,
#   786,
#   862,
#   741,
#   788,
#   823,
#   806,
#   702,
#   723,
#   668,
#   760,
#   783,
#   798,
#   823,
#   845,
#   555,
#   550,
#   813,
#   714,
#   631,
#   660,
#   641,
#   666,
#   703,
#   617,
#   704,
#   628,
#   759,
#   682,
#   628,
#   772,
#   703,
#   800,
#   597,
#   651,
#   594,
#   664,
#   670,
#   578,
#   637,
#   763,
#   584,
#   708,
#   774,
#   669,
#   693,
#   702,
#   632,
#   604,
#   617,
#   647,
#   690,
#   554,
#   740,
#   707,
#   632,
#   698,
#   683,
#   712,
#   629,
#   637,
#   642,
#   694,
#   699,
#   632,
#   695,
#   731,
#   682,
#   669,
#   699,
#   690,
#   682,
#   690,
#   693,
#   732,
#   750,
#   573,
#   707,
#   728,
#   666,
#   732,
#   662,
#   603,
#   775,
#   733,
#   646,
#   733,
#   673,
#   640,
#   719,
#   599,
#   676,
#   767,
#   749,
#   686,
#   731,
#   653,
#   758,
#   695,
#   689,
#   576,
#   817,
#   605,
#   727,
#   665,
#   776,
#   799,
#   579,
#   674,
#   640,
#   760,
#   629,
#   768,
#   636,
#   702,
#   649,
#   651,
#   829,
#   684,
#   682,
#   705,
#   599,
#   579,
#   738,
#   593,
#   660,
#   674,
#   791,
#   608,
#   610,
#   548,
#   747,
#   740,
#   648,
#   733,
#   599,
#   745,
#   686,
#   693,
#   617,
#   679,
#   574,
#   631,
#   682,
#   780,
#   767,
#   786,
#   686,
#   684,
#   776,
#   738,
#   722,
#   790,
#   758,
#   899,
#   581,
#   716,
#   675,
#   675,
#   693,
#   733,
#   732,
#   821,
#   672,
#   715,
#   877,
#   707,
#   679,
#   734,
#   808,
#   758,
#   835,
#   847,
#   542,
#   589,
#   552,
#   543,
#   633,
#   500,
#   609,
#   679,
#   573,
#   652,
#   468,
#   602,
#   574,
#   532,
#   594,
#   547,
#   585,
#   670,
#   506,
#   549,
#   521,
#   466,
#   479,
#   569,
#   504,
#   535,
#   613,
#   566,
#   645,
#   704,
#   791,
#   801,
#   755,
#   693,
#   747,
#   840,
#   785,
#   654,
#   673,
#   747,
#   629,
#   634,
#   703,
#   740,
#   621,
#   749,
#   657,
#   730,
#   615,
#   629,
#   668,
#   796,
#   652,
#   563,
#   691,
#   642,
#   773,
#   949,
#   928,
#   762,
#   898,
#   772,
#   778,
#   952,
#   961,
#   783,
#   688,
#   753,
#   746,
#   703,
#   877,
#   894,
#   741,
#   871,
#   746,
#   861,
#   650,
#   776,
#   771,
#   993,
#   752,
#   759,
#   928,
#   766,
#   829,
#   791,
#   812,
#   851,
#   779,
#   687,
#   651,
#   868,
#   923,
#   784,
#   740,
#   777,
#   747,
#   742,
#   772,
#   681,
#   691,
#   891,
#   777,
#   764,
#   668,
#   725,
#   795,
#   925,
#   784,
#   689,
#   807,
#   654,
#   787,
#   665,
#   826,
#   817,
#   876,
#   861,
#   831,
#   750,
#   850,
#   826,
#   722,
#   667,
#   874,
#   714,
#   669,
#   707,
#   734,
#   644,
#   965,
#   706,
#   804,
#   713,
#   650,
#   749,
#   859,
#   845,
#   810,
#   620,
#   940,
#   816,
#   711,
#   908,
#   840,
#   851,
#   836,
#   777,
#   747,
#   865,
#   1009,
#   906,
#   747,
#   691,
#   823,
#   856,
#   793,
#   815,
#   686,
#   718,
#   900,
#   853,
#   893,
#   841,
#   775,
#   710,
#   859,
#   872,
#   809,
#   772,
#   945,
#   883,
#   864,
#   792,
#   810,
#   794,
#   792,
#   978,
#   764,
#   825,
#   950,
#   968,
#   823,
#   731,
#   938,
#   879,
#   798,
#   740,
#   748,
#   738,
#   871,
#   807,
#   947,
#   708,
#   793,
#   752,
#   907,
#   925,
#   887,
#   733,
#   848,
#   861,
#   691,
#   818,
#   729,
#   687,
#   772,
#   798,
#   777,
#   735,
#   897,
#   923,
#   724,
#   742,
#   847,
#   729,
#   758,
#   740,
#   771,
#   670,
#   804,
#   642,
#   884,
#   746,
#   657,
#   789,
#   927,
#   799,
#   814,
#   672,
#   890,
#   767,
#   851,
#   819,
#   708,
#   667,
#   859,
#   856,
#   706,
#   709,
#   739,
#   778,
#   575,
#   699,
#   749,
#   737,
#   713,
#   627,
#   768,
#   735,
#   897,
#   690,
#   800,
#   710,
#   641,
#   662,
#   814,
#   783,
#   787,
#   673,
#   843,
#   813,
#   736,
#   717,
#   907,
#   743,
#   961,
#   791,
#   724,
#   694,
#   699,
#   853,
#   591,
#   751,
#   805,
#   836,
#   574,
#   714,
#   801,
#   711,
#   877,
#   642,
#   768,
#   791,
#   753,
#   678,
#   795,
#   755,
#   876,
#   715,
#   826,
#   894,
#   836,
#   615,
#   803,
#   842,
#   949,
#   865,
#   789,
#   750,
#   858,
#   833,
#   827,
#   718,
#   803,
#   720,
#   761,
#   634,
#   780,
#   635,
#   897,
#   684,
#   793,
#   840,
#   680,
#   768,
#   698,
#   850,
#   855,
#   714,
#   860,
#   719,
#   696,
#   769,
#   729,
#   910,
#   741,
#   703,
#   820,
#   790,
#   740,
#   723,
#   717,
#   693,
#   701,
#   761,
#   685,
#   726,
#   688,
#   886,
#   722,
#   772,
#   807,
#   680,
#   684,
#   699,
#   649,
#   805,
#   750,
#   865,
#   775,
#   639,
#   773,
#   849,
#   768,
#   820,
#   868,
#   716,
#   749,
#   870,
#   813,
#   822,
#   758,
#   735,
#   757,
#   766,
#   820,
#   730,
#   801,
#   930,
#   834,
#   771,
#   865,
#   691,
#   731,
#   756,
#   746,
#   781,
#   689,
#   835,
#   809,
#   746,
#   712,
#   810,
#   756,
#   867,
#   693,
#   752,
#   ...],
#  'Wins': [76,
#   108,
#   87,
#   86,
#   56,
#   84,
#   102,
#   76,
#   79,
#   79,
#   65,
#   87,
#   98,
#   65,
#   73,
#   93,
#   83,
#   89,
#   73,
#   89,
#   63,
#   86,
#   76,
#   70,
#   82,
#   101,
#   85,
#   76,
#   79,
#   83,
#   79,
#   60,
#   91,
#   79,
#   85,
#   89,
#   74,
#   69,
#   71,
#   82,
#   83,
#   101,
#   67,
#   97,
#   61,
#   90,
#   90,
#   63,
#   70,
#   80,
#   85,
#   75,
#   87,
#   85,
#   95,
#   72,
#   86,
#   84,
#   76,
#   85,
#   77,
#   65,
#   70,
#   79,
#   83,
#   93,
#   59,
#   96,
#   58,
#   69,
#   75,
#   54,
#   76,
#   97,
#   89,
#   79,
#   77,
#   77,
#   99,
#   71,
#   85,
#   82,
#   88,
#   95,
#   81,
#   74,
#   79,
#   80,
#   82,
#   94,
#   71,
#   80,
#   60,
#   88,
#   81,
#   57,
#   88,
#   91,
#   84,
#   68,
#   80,
#   66,
#   98,
#   77,
#   72,
#   81,
#   77,
#   102,
#   82,
#   76,
#   79,
#   89,
#   71,
#   90,
#   80,
#   88,
#   60,
#   72,
#   86,
#   84,
#   67,
#   90,
#   95,
#   72,
#   75,
#   75,
#   108,
#   79,
#   57,
#   64,
#   91,
#   88,
#   76,
#   68,
#   75,
#   83,
#   82,
#   98,
#   86,
#   92,
#   71,
#   80,
#   82,
#   79,
#   70,
#   88,
#   83,
#   76,
#   64,
#   75,
#   102,
#   81,
#   74,
#   80,
#   90,
#   92,
#   85,
#   66,
#   55,
#   97,
#   86,
#   87,
#   101,
#   92,
#   73,
#   74,
#   72,
#   76,
#   61,
#   97,
#   97,
#   74,
#   90,
#   81,
#   88,
#   71,
#   74,
#   81,
#   102,
#   98,
#   84,
#   67,
#   75,
#   100,
#   64,
#   63,
#   101,
#   96,
#   69,
#   64,
#   75,
#   83,
#   94,
#   54,
#   69,
#   90,
#   99,
#   87,
#   71,
#   79,
#   92,
#   69,
#   86,
#   74,
#   92,
#   95,
#   73,
#   93,
#   76,
#   100,
#   66,
#   69,
#   90,
#   88,
#   84,
#   56,
#   89,
#   69,
#   87,
#   59,
#   66,
#   102,
#   91,
#   88,
#   73,
#   80,
#   90,
#   81,
#   85,
#   89,
#   85,
#   79,
#   82,
#   95,
#   95,
#   89,
#   63,
#   54,
#   84,
#   98,
#   68,
#   67,
#   71,
#   86,
#   83,
#   53,
#   81,
#   100,
#   83,
#   65,
#   70,
#   64,
#   89,
#   79,
#   84,
#   93,
#   97,
#   92,
#   77,
#   86,
#   90,
#   103,
#   67,
#   83,
#   91,
#   83,
#   73,
#   59,
#   75,
#   74,
#   76,
#   67,
#   50,
#   59,
#   59,
#   51,
#   54,
#   38,
#   66,
#   52,
#   60,
#   61,
#   50,
#   63,
#   41,
#   62,
#   60,
#   59,
#   41,
#   64,
#   59,
#   46,
#   41,
#   44,
#   56,
#   59,
#   57,
#   37,
#   89,
#   94,
#   89,
#   93,
#   87,
#   73,
#   61,
#   78,
#   83,
#   77,
#   90,
#   88,
#   60,
#   95,
#   86,
#   79,
#   65,
#   68,
#   89,
#   84,
#   81,
#   76,
#   87,
#   92,
#   64,
#   78,
#   88,
#   98,
#   78,
#   70,
#   99,
#   71,
#   74,
#   70,
#   92,
#   85,
#   79,
#   91,
#   70,
#   87,
#   82,
#   91,
#   68,
#   74,
#   90,
#   84,
#   81,
#   60,
#   79,
#   79,
#   77,
#   89,
#   80,
#   85,
#   86,
#   81,
#   74,
#   96,
#   70,
#   75,
#   104,
#   80,
#   84,
#   79,
#   81,
#   67,
#   78,
#   87,
#   90,
#   77,
#   81,
#   75,
#   92,
#   74,
#   66,
#   84,
#   69,
#   89,
#   66,
#   83,
#   81,
#   90,
#   85,
#   77,
#   89,
#   60,
#   84,
#   83,
#   91,
#   95,
#   77,
#   71,
#   84,
#   97,
#   98,
#   77,
#   75,
#   57,
#   83,
#   74,
#   62,
#   101,
#   62,
#   99,
#   72,
#   73,
#   95,
#   92,
#   72,
#   70,
#   86,
#   84,
#   87,
#   96,
#   76,
#   73,
#   71,
#   77,
#   78,
#   90,
#   108,
#   76,
#   86,
#   64,
#   74,
#   67,
#   83,
#   79,
#   87,
#   86,
#   69,
#   67,
#   78,
#   75,
#   77,
#   76,
#   84,
#   61,
#   98,
#   76,
#   83,
#   73,
#   85,
#   91,
#   91,
#   89,
#   92,
#   81,
#   80,
#   80,
#   65,
#   78,
#   90,
#   95,
#   75,
#   96,
#   54,
#   54,
#   89,
#   75,
#   71,
#   77,
#   87,
#   78,
#   88,
#   82,
#   84,
#   94,
#   91,
#   87,
#   81,
#   85,
#   100,
#   104,
#   65,
#   85,
#   83,
#   68,
#   83,
#   76,
#   70,
#   87,
#   63,
#   87,
#   83,
#   91,
#   69,
#   93,
#   75,
#   73,
#   59,
#   86,
#   92,
#   77,
#   80,
#   81,
#   81,
#   74,
#   87,
#   99,
#   67,
#   74,
#   89,
#   73,
#   92,
#   86,
#   83,
#   89,
#   65,
#   76,
#   88,
#   80,
#   94,
#   77,
#   91,
#   77,
#   79,
#   75,
#   75,
#   86,
#   74,
#   74,
#   85,
#   67,
#   91,
#   103,
#   77,
#   95,
#   75,
#   77,
#   85,
#   70,
#   83,
#   86,
#   94,
#   67,
#   84,
#   81,
#   87,
#   77,
#   74,
#   57,
#   84,
#   65,
#   82,
#   93,
#   95,
#   83,
#   71,
#   71,
#   77,
#   84,
#   78,
#   98,
#   84,
#   83,
#   75,
#   84,
#   85,
#   91,
#   98,
#   89,
#   73,
#   72,
#   86,
#   78,
#   90,
#   76,
#   75,
#   81,
#   72,
#   63,
#   90,
#   92,
#   87,
#   76,
#   72,
#   96,
#   70,
#   96,
#   82,
#   64,
#   72,
#   83,
#   77,
#   96,
#   104,
#   85,
#   80,
#   71,
#   94,
#   84,
#   73,
#   76,
#   67,
#   85,
#   64,
#   85,
#   84,
#   81,
#   71,
#   69,
#   94,
#   88,
#   59,
#   68,
#   97,
#   75,
#   61,
#   82,
#   103,
#   87,
#   86,
#   95,
#   68,
#   63,
#   54,
#   47,
#   67,
#   49,
#   66,
#   66,
#   53,
#   53,
#   51,
#   66,
#   64,
#   58,
#   53,
#   53,
#   74,
#   70,
#   55,
#   51,
#   54,
#   53,
#   47,
#   49,
#   55,
#   53,
#   52,
#   55,
#   90,
#   71,
#   86,
#   78,
#   68,
#   73,
#   85,
#   100,
#   77,
#   60,
#   67,
#   76,
#   70,
#   78,
#   56,
#   65,
#   66,
#   79,
#   69,
#   67,
#   69,
#   58,
#   70,
#   79,
#   67,
#   62,
#   74,
#   56,
#   96,
#   88,
#   85,
#   70,
#   85,
#   76,
#   81,
#   99,
#   83,
#   53,
#   80,
#   82,
#   75,
#   90,
#   78,
#   80,
#   88,
#   92,
#   71,
#   78,
#   67,
#   73,
#   91,
#   85,
#   68,
#   88,
#   90,
#   74,
#   84,
#   101,
#   98,
#   78,
#   80,
#   68,
#   76,
#   86,
#   83,
#   79,
#   92,
#   84,
#   67,
#   88,
#   68,
#   78,
#   78,
#   96,
#   88,
#   65,
#   68,
#   79,
#   76,
#   90,
#   90,
#   73,
#   77,
#   76,
#   85,
#   65,
#   106,
#   79,
#   92,
#   80,
#   90,
#   77,
#   89,
#   77,
#   65,
#   54,
#   102,
#   72,
#   83,
#   74,
#   70,
#   65,
#   114,
#   88,
#   74,
#   75,
#   69,
#   98,
#   76,
#   89,
#   83,
#   63,
#   88,
#   88,
#   70,
#   100,
#   103,
#   78,
#   94,
#   75,
#   67,
#   96,
#   97,
#   72,
#   69,
#   64,
#   97,
#   64,
#   77,
#   74,
#   63,
#   68,
#   98,
#   97,
#   87,
#   77,
#   78,
#   74,
#   79,
#   86,
#   75,
#   69,
#   95,
#   84,
#   82,
#   85,
#   95,
#   74,
#   85,
#   95,
#   65,
#   85,
#   90,
#   82,
#   79,
#   79,
#   72,
#   77,
#   86,
#   73,
#   69,
#   67,
#   87,
#   94,
#   91,
#   65,
#   69,
#   76,
#   91,
#   97,
#   95,
#   69,
#   71,
#   83,
#   75,
#   92,
#   88,
#   63,
#   82,
#   83,
#   88,
#   66,
#   91,
#   73,
#   66,
#   76,
#   93,
#   65,
#   86,
#   68,
#   85,
#   68,
#   95,
#   82,
#   102,
#   86,
#   62,
#   79,
#   116,
#   90,
#   93,
#   62,
#   73,
#   80,
#   99,
#   98,
#   101,
#   67,
#   93,
#   81,
#   67,
#   78,
#   74,
#   73,
#   55,
#   79,
#   84,
#   62,
#   92,
#   56,
#   94,
#   83,
#   103,
#   75,
#   103,
#   80,
#   72,
#   66,
#   93,
#   95,
#   97,
#   55,
#   72,
#   78,
#   77,
#   84,
#   101,
#   71,
#   95,
#   86,
#   88,
#   69,
#   68,
#   74,
#   43,
#   91,
#   87,
#   83,
#   85,
#   68,
#   90,
#   83,
#   101,
#   66,
#   96,
#   86,
#   75,
#   64,
#   93,
#   100,
#   85,
#   63,
#   71,
#   86,
#   92,
#   51,
#   96,
#   78,
#   98,
#   83,
#   89,
#   76,
#   80,
#   68,
#   72,
#   83,
#   92,
#   58,
#   93,
#   67,
#   92,
#   67,
#   101,
#   71,
#   91,
#   86,
#   72,
#   87,
#   63,
#   91,
#   105,
#   70,
#   89,
#   67,
#   77,
#   90,
#   74,
#   95,
#   99,
#   79,
#   73,
#   93,
#   67,
#   71,
#   83,
#   89,
#   56,
#   95,
#   71,
#   81,
#   83,
#   95,
#   83,
#   88,
#   88,
#   67,
#   82,
#   69,
#   75,
#   100,
#   67,
#   79,
#   80,
#   81,
#   76,
#   79,
#   70,
#   86,
#   90,
#   66,
#   80,
#   78,
#   76,
#   95,
#   78,
#   82,
#   62,
#   89,
#   88,
#   75,
#   96,
#   97,
#   97,
#   93,
#   85,
#   67,
#   88,
#   78,
#   76,
#   83,
#   61,
#   80,
#   87,
#   71,
#   90,
#   84,
#   69,
#   96,
#   72,
#   85,
#   ...],
#  'Label': [[736, 76, 1970, 'ATL'],
#   [792, 108, 1970, 'BAL'],
#   [786, 87, 1970, 'BOS'],
#   [631, 86, 1970, 'ANA'],
#   [633, 56, 1970, 'CHW'],
#   [806, 84, 1970, 'CHC'],
#   [775, 102, 1970, 'CIN'],
#   [649, 76, 1970, 'CLE'],
#   [666, 79, 1970, 'DET'],
#   [744, 79, 1970, 'HOU'],
#   [611, 65, 1970, 'KCR'],
#   [749, 87, 1970, 'LAD'],
#   [744, 98, 1970, 'MIN'],
#   [613, 65, 1970, 'MIL'],
#   [687, 73, 1970, 'WSN'],
#   [680, 93, 1970, 'NYY'],
#   [695, 83, 1970, 'NYM'],
#   [678, 89, 1970, 'OAK'],
#   [594, 73, 1970, 'PHI'],
#   [729, 89, 1970, 'PIT'],
#   [681, 63, 1970, 'SDP'],
#   [831, 86, 1970, 'SFG'],
#   [744, 76, 1970, 'STL'],
#   [626, 70, 1970, 'TEX'],
#   [643, 82, 1971, 'ATL'],
#   [742, 101, 1971, 'BAL'],
#   [691, 85, 1971, 'BOS'],
#   [511, 76, 1971, 'ANA'],
#   [617, 79, 1971, 'CHW'],
#   [637, 83, 1971, 'CHC'],
#   [586, 79, 1971, 'CIN'],
#   [543, 60, 1971, 'CLE'],
#   [701, 91, 1971, 'DET'],
#   [585, 79, 1971, 'HOU'],
#   [603, 85, 1971, 'KCR'],
#   [663, 89, 1971, 'LAD'],
#   [654, 74, 1971, 'MIN'],
#   [534, 69, 1971, 'MIL'],
#   [622, 71, 1971, 'WSN'],
#   [648, 82, 1971, 'NYY'],
#   [588, 83, 1971, 'NYM'],
#   [691, 101, 1971, 'OAK'],
#   [558, 67, 1971, 'PHI'],
#   [788, 97, 1971, 'PIT'],
#   [486, 61, 1971, 'SDP'],
#   [706, 90, 1971, 'SFG'],
#   [739, 90, 1971, 'STL'],
#   [537, 63, 1971, 'TEX'],
#   [628, 70, 1972, 'ATL'],
#   [519, 80, 1972, 'BAL'],
#   [640, 85, 1972, 'BOS'],
#   [454, 75, 1972, 'ANA'],
#   [566, 87, 1972, 'CHW'],
#   [685, 85, 1972, 'CHC'],
#   [707, 95, 1972, 'CIN'],
#   [472, 72, 1972, 'CLE'],
#   [558, 86, 1972, 'DET'],
#   [708, 84, 1972, 'HOU'],
#   [580, 76, 1972, 'KCR'],
#   [584, 85, 1972, 'LAD'],
#   [537, 77, 1972, 'MIN'],
#   [493, 65, 1972, 'MIL'],
#   [513, 70, 1972, 'WSN'],
#   [557, 79, 1972, 'NYY'],
#   [528, 83, 1972, 'NYM'],
#   [604, 93, 1972, 'OAK'],
#   [503, 59, 1972, 'PHI'],
#   [691, 96, 1972, 'PIT'],
#   [488, 58, 1972, 'SDP'],
#   [662, 69, 1972, 'SFG'],
#   [568, 75, 1972, 'STL'],
#   [461, 54, 1972, 'TEX'],
#   [799, 76, 1973, 'ATL'],
#   [754, 97, 1973, 'BAL'],
#   [738, 89, 1973, 'BOS'],
#   [629, 79, 1973, 'ANA'],
#   [652, 77, 1973, 'CHW'],
#   [614, 77, 1973, 'CHC'],
#   [741, 99, 1973, 'CIN'],
#   [680, 71, 1973, 'CLE'],
#   [642, 85, 1973, 'DET'],
#   [681, 82, 1973, 'HOU'],
#   [755, 88, 1973, 'KCR'],
#   [675, 95, 1973, 'LAD'],
#   [738, 81, 1973, 'MIN'],
#   [708, 74, 1973, 'MIL'],
#   [668, 79, 1973, 'WSN'],
#   [641, 80, 1973, 'NYY'],
#   [608, 82, 1973, 'NYM'],
#   [758, 94, 1973, 'OAK'],
#   [642, 71, 1973, 'PHI'],
#   [704, 80, 1973, 'PIT'],
#   [548, 60, 1973, 'SDP'],
#   [739, 88, 1973, 'SFG'],
#   [643, 81, 1973, 'STL'],
#   [619, 57, 1973, 'TEX'],
#   [661, 88, 1974, 'ATL'],
#   [659, 91, 1974, 'BAL'],
#   [696, 84, 1974, 'BOS'],
#   [618, 68, 1974, 'ANA'],
#   [684, 80, 1974, 'CHW'],
#   [669, 66, 1974, 'CHC'],
#   [776, 98, 1974, 'CIN'],
#   [662, 77, 1974, 'CLE'],
#   [620, 72, 1974, 'DET'],
#   [653, 81, 1974, 'HOU'],
#   [667, 77, 1974, 'KCR'],
#   [798, 102, 1974, 'LAD'],
#   [673, 82, 1974, 'MIN'],
#   [647, 76, 1974, 'MIL'],
#   [662, 79, 1974, 'WSN'],
#   [671, 89, 1974, 'NYY'],
#   [572, 71, 1974, 'NYM'],
#   [689, 90, 1974, 'OAK'],
#   [676, 80, 1974, 'PHI'],
#   [751, 88, 1974, 'PIT'],
#   [541, 60, 1974, 'SDP'],
#   [634, 72, 1974, 'SFG'],
#   [677, 86, 1974, 'STL'],
#   [690, 84, 1974, 'TEX'],
#   [583, 67, 1975, 'ATL'],
#   [682, 90, 1975, 'BAL'],
#   [796, 95, 1975, 'BOS'],
#   [628, 72, 1975, 'ANA'],
#   [655, 75, 1975, 'CHW'],
#   [712, 75, 1975, 'CHC'],
#   [840, 108, 1975, 'CIN'],
#   [688, 79, 1975, 'CLE'],
#   [570, 57, 1975, 'DET'],
#   [664, 64, 1975, 'HOU'],
#   [710, 91, 1975, 'KCR'],
#   [648, 88, 1975, 'LAD'],
#   [724, 76, 1975, 'MIN'],
#   [675, 68, 1975, 'MIL'],
#   [601, 75, 1975, 'WSN'],
#   [681, 83, 1975, 'NYY'],
#   [646, 82, 1975, 'NYM'],
#   [758, 98, 1975, 'OAK'],
#   [735, 86, 1975, 'PHI'],
#   [712, 92, 1975, 'PIT'],
#   [552, 71, 1975, 'SDP'],
#   [659, 80, 1975, 'SFG'],
#   [662, 82, 1975, 'STL'],
#   [714, 79, 1975, 'TEX'],
#   [620, 70, 1976, 'ATL'],
#   [619, 88, 1976, 'BAL'],
#   [716, 83, 1976, 'BOS'],
#   [550, 76, 1976, 'ANA'],
#   [586, 64, 1976, 'CHW'],
#   [611, 75, 1976, 'CHC'],
#   [857, 102, 1976, 'CIN'],
#   [615, 81, 1976, 'CLE'],
#   [609, 74, 1976, 'DET'],
#   [625, 80, 1976, 'HOU'],
#   [713, 90, 1976, 'KCR'],
#   [608, 92, 1976, 'LAD'],
#   [743, 85, 1976, 'MIN'],
#   [570, 66, 1976, 'MIL'],
#   [531, 55, 1976, 'WSN'],
#   [730, 97, 1976, 'NYY'],
#   [615, 86, 1976, 'NYM'],
#   [686, 87, 1976, 'OAK'],
#   [770, 101, 1976, 'PHI'],
#   [708, 92, 1976, 'PIT'],
#   [570, 73, 1976, 'SDP'],
#   [595, 74, 1976, 'SFG'],
#   [629, 72, 1976, 'STL'],
#   [616, 76, 1976, 'TEX'],
#   [678, 61, 1977, 'ATL'],
#   [719, 97, 1977, 'BAL'],
#   [859, 97, 1977, 'BOS'],
#   [675, 74, 1977, 'ANA'],
#   [844, 90, 1977, 'CHW'],
#   [692, 81, 1977, 'CHC'],
#   [802, 88, 1977, 'CIN'],
#   [676, 71, 1977, 'CLE'],
#   [714, 74, 1977, 'DET'],
#   [680, 81, 1977, 'HOU'],
#   [822, 102, 1977, 'KCR'],
#   [769, 98, 1977, 'LAD'],
#   [867, 84, 1977, 'MIN'],
#   [639, 67, 1977, 'MIL'],
#   [665, 75, 1977, 'WSN'],
#   [831, 100, 1977, 'NYY'],
#   [587, 64, 1977, 'NYM'],
#   [605, 63, 1977, 'OAK'],
#   [847, 101, 1977, 'PHI'],
#   [734, 96, 1977, 'PIT'],
#   [692, 69, 1977, 'SDP'],
#   [624, 64, 1977, 'SEA'],
#   [673, 75, 1977, 'SFG'],
#   [737, 83, 1977, 'STL'],
#   [767, 94, 1977, 'TEX'],
#   [605, 54, 1977, 'TOR'],
#   [600, 69, 1978, 'ATL'],
#   [659, 90, 1978, 'BAL'],
#   [796, 99, 1978, 'BOS'],
#   [691, 87, 1978, 'ANA'],
#   [634, 71, 1978, 'CHW'],
#   [664, 79, 1978, 'CHC'],
#   [710, 92, 1978, 'CIN'],
#   [639, 69, 1978, 'CLE'],
#   [714, 86, 1978, 'DET'],
#   [605, 74, 1978, 'HOU'],
#   [743, 92, 1978, 'KCR'],
#   [727, 95, 1978, 'LAD'],
#   [666, 73, 1978, 'MIN'],
#   [804, 93, 1978, 'MIL'],
#   [633, 76, 1978, 'WSN'],
#   [735, 100, 1978, 'NYY'],
#   [607, 66, 1978, 'NYM'],
#   [532, 69, 1978, 'OAK'],
#   [708, 90, 1978, 'PHI'],
#   [684, 88, 1978, 'PIT'],
#   [591, 84, 1978, 'SDP'],
#   [614, 56, 1978, 'SEA'],
#   [613, 89, 1978, 'SFG'],
#   [600, 69, 1978, 'STL'],
#   [692, 87, 1978, 'TEX'],
#   [590, 59, 1978, 'TOR'],
#   [669, 66, 1979, 'ATL'],
#   [757, 102, 1979, 'BAL'],
#   [841, 91, 1979, 'BOS'],
#   [866, 88, 1979, 'ANA'],
#   [730, 73, 1979, 'CHW'],
#   [706, 80, 1979, 'CHC'],
#   [731, 90, 1979, 'CIN'],
#   [760, 81, 1979, 'CLE'],
#   [770, 85, 1979, 'DET'],
#   [583, 89, 1979, 'HOU'],
#   [851, 85, 1979, 'KCR'],
#   [739, 79, 1979, 'LAD'],
#   [764, 82, 1979, 'MIN'],
#   [807, 95, 1979, 'MIL'],
#   [701, 95, 1979, 'WSN'],
#   [734, 89, 1979, 'NYY'],
#   [593, 63, 1979, 'NYM'],
#   [573, 54, 1979, 'OAK'],
#   [683, 84, 1979, 'PHI'],
#   [775, 98, 1979, 'PIT'],
#   [603, 68, 1979, 'SDP'],
#   [711, 67, 1979, 'SEA'],
#   [672, 71, 1979, 'SFG'],
#   [731, 86, 1979, 'STL'],
#   [750, 83, 1979, 'TEX'],
#   [613, 53, 1979, 'TOR'],
#   [630, 81, 1980, 'ATL'],
#   [805, 100, 1980, 'BAL'],
#   [757, 83, 1980, 'BOS'],
#   [698, 65, 1980, 'ANA'],
#   [587, 70, 1980, 'CHW'],
#   [614, 64, 1980, 'CHC'],
#   [707, 89, 1980, 'CIN'],
#   [738, 79, 1980, 'CLE'],
#   [830, 84, 1980, 'DET'],
#   [637, 93, 1980, 'HOU'],
#   [809, 97, 1980, 'KCR'],
#   [663, 92, 1980, 'LAD'],
#   [670, 77, 1980, 'MIN'],
#   [811, 86, 1980, 'MIL'],
#   [694, 90, 1980, 'WSN'],
#   [820, 103, 1980, 'NYY'],
#   [611, 67, 1980, 'NYM'],
#   [686, 83, 1980, 'OAK'],
#   [728, 91, 1980, 'PHI'],
#   [666, 83, 1980, 'PIT'],
#   [591, 73, 1980, 'SDP'],
#   [610, 59, 1980, 'SEA'],
#   [573, 75, 1980, 'SFG'],
#   [738, 74, 1980, 'STL'],
#   [756, 76, 1980, 'TEX'],
#   [624, 67, 1980, 'TOR'],
#   [395, 50, 1981, 'ATL'],
#   [429, 59, 1981, 'BAL'],
#   [519, 59, 1981, 'BOS'],
#   [476, 51, 1981, 'ANA'],
#   [476, 54, 1981, 'CHW'],
#   [370, 38, 1981, 'CHC'],
#   [464, 66, 1981, 'CIN'],
#   [431, 52, 1981, 'CLE'],
#   [427, 60, 1981, 'DET'],
#   [394, 61, 1981, 'HOU'],
#   [397, 50, 1981, 'KCR'],
#   [450, 63, 1981, 'LAD'],
#   [378, 41, 1981, 'MIN'],
#   [493, 62, 1981, 'MIL'],
#   [443, 60, 1981, 'WSN'],
#   [421, 59, 1981, 'NYY'],
#   [348, 41, 1981, 'NYM'],
#   [458, 64, 1981, 'OAK'],
#   [491, 59, 1981, 'PHI'],
#   [407, 46, 1981, 'PIT'],
#   [382, 41, 1981, 'SDP'],
#   [426, 44, 1981, 'SEA'],
#   [427, 56, 1981, 'SFG'],
#   [464, 59, 1981, 'STL'],
#   [452, 57, 1981, 'TEX'],
#   [329, 37, 1981, 'TOR'],
#   [739, 89, 1982, 'ATL'],
#   [774, 94, 1982, 'BAL'],
#   [753, 89, 1982, 'BOS'],
#   [814, 93, 1982, 'ANA'],
#   [786, 87, 1982, 'CHW'],
#   [676, 73, 1982, 'CHC'],
#   [545, 61, 1982, 'CIN'],
#   [683, 78, 1982, 'CLE'],
#   [729, 83, 1982, 'DET'],
#   [569, 77, 1982, 'HOU'],
#   [784, 90, 1982, 'KCR'],
#   [691, 88, 1982, 'LAD'],
#   [657, 60, 1982, 'MIN'],
#   [891, 95, 1982, 'MIL'],
#   [697, 86, 1982, 'WSN'],
#   [709, 79, 1982, 'NYY'],
#   [609, 65, 1982, 'NYM'],
#   [691, 68, 1982, 'OAK'],
#   [664, 89, 1982, 'PHI'],
#   [724, 84, 1982, 'PIT'],
#   [675, 81, 1982, 'SDP'],
#   [651, 76, 1982, 'SEA'],
#   [673, 87, 1982, 'SFG'],
#   [685, 92, 1982, 'STL'],
#   [590, 64, 1982, 'TEX'],
#   [651, 78, 1982, 'TOR'],
#   [746, 88, 1983, 'ATL'],
#   [799, 98, 1983, 'BAL'],
#   [724, 78, 1983, 'BOS'],
#   [722, 70, 1983, 'ANA'],
#   [800, 99, 1983, 'CHW'],
#   [701, 71, 1983, 'CHC'],
#   [623, 74, 1983, 'CIN'],
#   [704, 70, 1983, 'CLE'],
#   [789, 92, 1983, 'DET'],
#   [643, 85, 1983, 'HOU'],
#   [696, 79, 1983, 'KCR'],
#   [654, 91, 1983, 'LAD'],
#   [709, 70, 1983, 'MIN'],
#   [764, 87, 1983, 'MIL'],
#   [677, 82, 1983, 'WSN'],
#   [770, 91, 1983, 'NYY'],
#   [575, 68, 1983, 'NYM'],
#   [708, 74, 1983, 'OAK'],
#   [696, 90, 1983, 'PHI'],
#   [659, 84, 1983, 'PIT'],
#   [653, 81, 1983, 'SDP'],
#   [558, 60, 1983, 'SEA'],
#   [687, 79, 1983, 'SFG'],
#   [679, 79, 1983, 'STL'],
#   [639, 77, 1983, 'TEX'],
#   [795, 89, 1983, 'TOR'],
#   [632, 80, 1984, 'ATL'],
#   [681, 85, 1984, 'BAL'],
#   [810, 86, 1984, 'BOS'],
#   [696, 81, 1984, 'ANA'],
#   [679, 74, 1984, 'CHW'],
#   [762, 96, 1984, 'CHC'],
#   [627, 70, 1984, 'CIN'],
#   [761, 75, 1984, 'CLE'],
#   [829, 104, 1984, 'DET'],
#   [693, 80, 1984, 'HOU'],
#   [673, 84, 1984, 'KCR'],
#   [580, 79, 1984, 'LAD'],
#   [673, 81, 1984, 'MIN'],
#   [641, 67, 1984, 'MIL'],
#   [593, 78, 1984, 'WSN'],
#   [758, 87, 1984, 'NYY'],
#   [652, 90, 1984, 'NYM'],
#   [738, 77, 1984, 'OAK'],
#   [720, 81, 1984, 'PHI'],
#   [615, 75, 1984, 'PIT'],
#   [686, 92, 1984, 'SDP'],
#   [682, 74, 1984, 'SEA'],
#   [682, 66, 1984, 'SFG'],
#   [652, 84, 1984, 'STL'],
#   [656, 69, 1984, 'TEX'],
#   [750, 89, 1984, 'TOR'],
#   [632, 66, 1985, 'ATL'],
#   [818, 83, 1985, 'BAL'],
#   [800, 81, 1985, 'BOS'],
#   [732, 90, 1985, 'ANA'],
#   [736, 85, 1985, 'CHW'],
#   [686, 77, 1985, 'CHC'],
#   [677, 89, 1985, 'CIN'],
#   [729, 60, 1985, 'CLE'],
#   [729, 84, 1985, 'DET'],
#   [706, 83, 1985, 'HOU'],
#   [687, 91, 1985, 'KCR'],
#   [682, 95, 1985, 'LAD'],
#   [705, 77, 1985, 'MIN'],
#   [690, 71, 1985, 'MIL'],
#   [633, 84, 1985, 'WSN'],
#   [839, 97, 1985, 'NYY'],
#   [695, 98, 1985, 'NYM'],
#   [757, 77, 1985, 'OAK'],
#   [667, 75, 1985, 'PHI'],
#   [568, 57, 1985, 'PIT'],
#   [650, 83, 1985, 'SDP'],
#   [719, 74, 1985, 'SEA'],
#   [556, 62, 1985, 'SFG'],
#   [747, 101, 1985, 'STL'],
#   [617, 62, 1985, 'TEX'],
#   [759, 99, 1985, 'TOR'],
#   [615, 72, 1986, 'ATL'],
#   [708, 73, 1986, 'BAL'],
#   [794, 95, 1986, 'BOS'],
#   [786, 92, 1986, 'ANA'],
#   [644, 72, 1986, 'CHW'],
#   [680, 70, 1986, 'CHC'],
#   [732, 86, 1986, 'CIN'],
#   [831, 84, 1986, 'CLE'],
#   [798, 87, 1986, 'DET'],
#   [654, 96, 1986, 'HOU'],
#   [654, 76, 1986, 'KCR'],
#   [638, 73, 1986, 'LAD'],
#   [741, 71, 1986, 'MIN'],
#   [667, 77, 1986, 'MIL'],
#   [637, 78, 1986, 'WSN'],
#   [797, 90, 1986, 'NYY'],
#   [783, 108, 1986, 'NYM'],
#   [731, 76, 1986, 'OAK'],
#   [739, 86, 1986, 'PHI'],
#   [663, 64, 1986, 'PIT'],
#   [656, 74, 1986, 'SDP'],
#   [718, 67, 1986, 'SEA'],
#   [698, 83, 1986, 'SFG'],
#   [601, 79, 1986, 'STL'],
#   [771, 87, 1986, 'TEX'],
#   [809, 86, 1986, 'TOR'],
#   [747, 69, 1987, 'ATL'],
#   [729, 67, 1987, 'BAL'],
#   [842, 78, 1987, 'BOS'],
#   [770, 75, 1987, 'ANA'],
#   [748, 77, 1987, 'CHW'],
#   [720, 76, 1987, 'CHC'],
#   [783, 84, 1987, 'CIN'],
#   [742, 61, 1987, 'CLE'],
#   [896, 98, 1987, 'DET'],
#   [648, 76, 1987, 'HOU'],
#   [715, 83, 1987, 'KCR'],
#   [635, 73, 1987, 'LAD'],
#   [786, 85, 1987, 'MIN'],
#   [862, 91, 1987, 'MIL'],
#   [741, 91, 1987, 'WSN'],
#   [788, 89, 1987, 'NYY'],
#   [823, 92, 1987, 'NYM'],
#   [806, 81, 1987, 'OAK'],
#   [702, 80, 1987, 'PHI'],
#   [723, 80, 1987, 'PIT'],
#   [668, 65, 1987, 'SDP'],
#   [760, 78, 1987, 'SEA'],
#   [783, 90, 1987, 'SFG'],
#   [798, 95, 1987, 'STL'],
#   [823, 75, 1987, 'TEX'],
#   [845, 96, 1987, 'TOR'],
#   [555, 54, 1988, 'ATL'],
#   [550, 54, 1988, 'BAL'],
#   [813, 89, 1988, 'BOS'],
#   [714, 75, 1988, 'ANA'],
#   [631, 71, 1988, 'CHW'],
#   [660, 77, 1988, 'CHC'],
#   [641, 87, 1988, 'CIN'],
#   [666, 78, 1988, 'CLE'],
#   [703, 88, 1988, 'DET'],
#   [617, 82, 1988, 'HOU'],
#   [704, 84, 1988, 'KCR'],
#   [628, 94, 1988, 'LAD'],
#   [759, 91, 1988, 'MIN'],
#   [682, 87, 1988, 'MIL'],
#   [628, 81, 1988, 'WSN'],
#   [772, 85, 1988, 'NYY'],
#   [703, 100, 1988, 'NYM'],
#   [800, 104, 1988, 'OAK'],
#   [597, 65, 1988, 'PHI'],
#   [651, 85, 1988, 'PIT'],
#   [594, 83, 1988, 'SDP'],
#   [664, 68, 1988, 'SEA'],
#   [670, 83, 1988, 'SFG'],
#   [578, 76, 1988, 'STL'],
#   [637, 70, 1988, 'TEX'],
#   [763, 87, 1988, 'TOR'],
#   [584, 63, 1989, 'ATL'],
#   [708, 87, 1989, 'BAL'],
#   [774, 83, 1989, 'BOS'],
#   [669, 91, 1989, 'ANA'],
#   [693, 69, 1989, 'CHW'],
#   [702, 93, 1989, 'CHC'],
#   [632, 75, 1989, 'CIN'],
#   [604, 73, 1989, 'CLE'],
#   [617, 59, 1989, 'DET'],
#   [647, 86, 1989, 'HOU'],
#   [690, 92, 1989, 'KCR'],
#   [554, 77, 1989, 'LAD'],
#   [740, 80, 1989, 'MIN'],
#   [707, 81, 1989, 'MIL'],
#   [632, 81, 1989, 'WSN'],
#   [698, 74, 1989, 'NYY'],
#   [683, 87, 1989, 'NYM'],
#   [712, 99, 1989, 'OAK'],
#   [629, 67, 1989, 'PHI'],
#   [637, 74, 1989, 'PIT'],
#   [642, 89, 1989, 'SDP'],
#   [694, 73, 1989, 'SEA'],
#   [699, 92, 1989, 'SFG'],
#   [632, 86, 1989, 'STL'],
#   [695, 83, 1989, 'TEX'],
#   [731, 89, 1989, 'TOR'],
#   [682, 65, 1990, 'ATL'],
#   [669, 76, 1990, 'BAL'],
#   [699, 88, 1990, 'BOS'],
#   [690, 80, 1990, 'ANA'],
#   [682, 94, 1990, 'CHW'],
#   [690, 77, 1990, 'CHC'],
#   [693, 91, 1990, 'CIN'],
#   [732, 77, 1990, 'CLE'],
#   [750, 79, 1990, 'DET'],
#   [573, 75, 1990, 'HOU'],
#   [707, 75, 1990, 'KCR'],
#   [728, 86, 1990, 'LAD'],
#   [666, 74, 1990, 'MIN'],
#   [732, 74, 1990, 'MIL'],
#   [662, 85, 1990, 'WSN'],
#   [603, 67, 1990, 'NYY'],
#   [775, 91, 1990, 'NYM'],
#   [733, 103, 1990, 'OAK'],
#   [646, 77, 1990, 'PHI'],
#   [733, 95, 1990, 'PIT'],
#   [673, 75, 1990, 'SDP'],
#   [640, 77, 1990, 'SEA'],
#   [719, 85, 1990, 'SFG'],
#   [599, 70, 1990, 'STL'],
#   [676, 83, 1990, 'TEX'],
#   [767, 86, 1990, 'TOR'],
#   [749, 94, 1991, 'ATL'],
#   [686, 67, 1991, 'BAL'],
#   [731, 84, 1991, 'BOS'],
#   [653, 81, 1991, 'ANA'],
#   [758, 87, 1991, 'CHW'],
#   [695, 77, 1991, 'CHC'],
#   [689, 74, 1991, 'CIN'],
#   [576, 57, 1991, 'CLE'],
#   [817, 84, 1991, 'DET'],
#   [605, 65, 1991, 'HOU'],
#   [727, 82, 1991, 'KCR'],
#   [665, 93, 1991, 'LAD'],
#   [776, 95, 1991, 'MIN'],
#   [799, 83, 1991, 'MIL'],
#   [579, 71, 1991, 'WSN'],
#   [674, 71, 1991, 'NYY'],
#   [640, 77, 1991, 'NYM'],
#   [760, 84, 1991, 'OAK'],
#   [629, 78, 1991, 'PHI'],
#   [768, 98, 1991, 'PIT'],
#   [636, 84, 1991, 'SDP'],
#   [702, 83, 1991, 'SEA'],
#   [649, 75, 1991, 'SFG'],
#   [651, 84, 1991, 'STL'],
#   [829, 85, 1991, 'TEX'],
#   [684, 91, 1991, 'TOR'],
#   [682, 98, 1992, 'ATL'],
#   [705, 89, 1992, 'BAL'],
#   [599, 73, 1992, 'BOS'],
#   [579, 72, 1992, 'ANA'],
#   [738, 86, 1992, 'CHW'],
#   [593, 78, 1992, 'CHC'],
#   [660, 90, 1992, 'CIN'],
#   [674, 76, 1992, 'CLE'],
#   [791, 75, 1992, 'DET'],
#   [608, 81, 1992, 'HOU'],
#   [610, 72, 1992, 'KCR'],
#   [548, 63, 1992, 'LAD'],
#   [747, 90, 1992, 'MIN'],
#   [740, 92, 1992, 'MIL'],
#   [648, 87, 1992, 'WSN'],
#   [733, 76, 1992, 'NYY'],
#   [599, 72, 1992, 'NYM'],
#   [745, 96, 1992, 'OAK'],
#   [686, 70, 1992, 'PHI'],
#   [693, 96, 1992, 'PIT'],
#   [617, 82, 1992, 'SDP'],
#   [679, 64, 1992, 'SEA'],
#   [574, 72, 1992, 'SFG'],
#   [631, 83, 1992, 'STL'],
#   [682, 77, 1992, 'TEX'],
#   [780, 96, 1992, 'TOR'],
#   [767, 104, 1993, 'ATL'],
#   [786, 85, 1993, 'BAL'],
#   [686, 80, 1993, 'BOS'],
#   [684, 71, 1993, 'ANA'],
#   [776, 94, 1993, 'CHW'],
#   [738, 84, 1993, 'CHC'],
#   [722, 73, 1993, 'CIN'],
#   [790, 76, 1993, 'CLE'],
#   [758, 67, 1993, 'COL'],
#   [899, 85, 1993, 'DET'],
#   [581, 64, 1993, 'FLA'],
#   [716, 85, 1993, 'HOU'],
#   [675, 84, 1993, 'KCR'],
#   [675, 81, 1993, 'LAD'],
#   [693, 71, 1993, 'MIN'],
#   [733, 69, 1993, 'MIL'],
#   [732, 94, 1993, 'WSN'],
#   [821, 88, 1993, 'NYY'],
#   [672, 59, 1993, 'NYM'],
#   [715, 68, 1993, 'OAK'],
#   [877, 97, 1993, 'PHI'],
#   [707, 75, 1993, 'PIT'],
#   [679, 61, 1993, 'SDP'],
#   [734, 82, 1993, 'SEA'],
#   [808, 103, 1993, 'SFG'],
#   [758, 87, 1993, 'STL'],
#   [835, 86, 1993, 'TEX'],
#   [847, 95, 1993, 'TOR'],
#   [542, 68, 1994, 'ATL'],
#   [589, 63, 1994, 'BAL'],
#   [552, 54, 1994, 'BOS'],
#   [543, 47, 1994, 'ANA'],
#   [633, 67, 1994, 'CHW'],
#   [500, 49, 1994, 'CHC'],
#   [609, 66, 1994, 'CIN'],
#   [679, 66, 1994, 'CLE'],
#   [573, 53, 1994, 'COL'],
#   [652, 53, 1994, 'DET'],
#   [468, 51, 1994, 'FLA'],
#   [602, 66, 1994, 'HOU'],
#   [574, 64, 1994, 'KCR'],
#   [532, 58, 1994, 'LAD'],
#   [594, 53, 1994, 'MIN'],
#   [547, 53, 1994, 'MIL'],
#   [585, 74, 1994, 'WSN'],
#   [670, 70, 1994, 'NYY'],
#   [506, 55, 1994, 'NYM'],
#   [549, 51, 1994, 'OAK'],
#   [521, 54, 1994, 'PHI'],
#   [466, 53, 1994, 'PIT'],
#   [479, 47, 1994, 'SDP'],
#   [569, 49, 1994, 'SEA'],
#   [504, 55, 1994, 'SFG'],
#   [535, 53, 1994, 'STL'],
#   [613, 52, 1994, 'TEX'],
#   [566, 55, 1994, 'TOR'],
#   [645, 90, 1995, 'ATL'],
#   [704, 71, 1995, 'BAL'],
#   [791, 86, 1995, 'BOS'],
#   [801, 78, 1995, 'ANA'],
#   [755, 68, 1995, 'CHW'],
#   [693, 73, 1995, 'CHC'],
#   [747, 85, 1995, 'CIN'],
#   [840, 100, 1995, 'CLE'],
#   [785, 77, 1995, 'COL'],
#   [654, 60, 1995, 'DET'],
#   [673, 67, 1995, 'FLA'],
#   [747, 76, 1995, 'HOU'],
#   [629, 70, 1995, 'KCR'],
#   [634, 78, 1995, 'LAD'],
#   [703, 56, 1995, 'MIN'],
#   [740, 65, 1995, 'MIL'],
#   [621, 66, 1995, 'WSN'],
#   [749, 79, 1995, 'NYY'],
#   [657, 69, 1995, 'NYM'],
#   [730, 67, 1995, 'OAK'],
#   [615, 69, 1995, 'PHI'],
#   [629, 58, 1995, 'PIT'],
#   [668, 70, 1995, 'SDP'],
#   [796, 79, 1995, 'SEA'],
#   [652, 67, 1995, 'SFG'],
#   [563, 62, 1995, 'STL'],
#   [691, 74, 1995, 'TEX'],
#   [642, 56, 1995, 'TOR'],
#   [773, 96, 1996, 'ATL'],
#   [949, 88, 1996, 'BAL'],
#   [928, 85, 1996, 'BOS'],
#   [762, 70, 1996, 'ANA'],
#   [898, 85, 1996, 'CHW'],
#   [772, 76, 1996, 'CHC'],
#   [778, 81, 1996, 'CIN'],
#   [952, 99, 1996, 'CLE'],
#   [961, 83, 1996, 'COL'],
#   [783, 53, 1996, 'DET'],
#   [688, 80, 1996, 'FLA'],
#   [753, 82, 1996, 'HOU'],
#   [746, 75, 1996, 'KCR'],
#   [703, 90, 1996, 'LAD'],
#   [877, 78, 1996, 'MIN'],
#   [894, 80, 1996, 'MIL'],
#   [741, 88, 1996, 'WSN'],
#   [871, 92, 1996, 'NYY'],
#   [746, 71, 1996, 'NYM'],
#   [861, 78, 1996, 'OAK'],
#   [650, 67, 1996, 'PHI'],
#   [776, 73, 1996, 'PIT'],
#   [771, 91, 1996, 'SDP'],
#   [993, 85, 1996, 'SEA'],
#   [752, 68, 1996, 'SFG'],
#   [759, 88, 1996, 'STL'],
#   [928, 90, 1996, 'TEX'],
#   [766, 74, 1996, 'TOR'],
#   [829, 84, 1997, 'ANA'],
#   [791, 101, 1997, 'ATL'],
#   [812, 98, 1997, 'BAL'],
#   [851, 78, 1997, 'BOS'],
#   [779, 80, 1997, 'CHW'],
#   [687, 68, 1997, 'CHC'],
#   [651, 76, 1997, 'CIN'],
#   [868, 86, 1997, 'CLE'],
#   [923, 83, 1997, 'COL'],
#   [784, 79, 1997, 'DET'],
#   [740, 92, 1997, 'FLA'],
#   [777, 84, 1997, 'HOU'],
#   [747, 67, 1997, 'KCR'],
#   [742, 88, 1997, 'LAD'],
#   [772, 68, 1997, 'MIN'],
#   [681, 78, 1997, 'MIL'],
#   [691, 78, 1997, 'WSN'],
#   [891, 96, 1997, 'NYY'],
#   [777, 88, 1997, 'NYM'],
#   [764, 65, 1997, 'OAK'],
#   [668, 68, 1997, 'PHI'],
#   [725, 79, 1997, 'PIT'],
#   [795, 76, 1997, 'SDP'],
#   [925, 90, 1997, 'SEA'],
#   [784, 90, 1997, 'SFG'],
#   [689, 73, 1997, 'STL'],
#   [807, 77, 1997, 'TEX'],
#   [654, 76, 1997, 'TOR'],
#   [787, 85, 1998, 'ANA'],
#   [665, 65, 1998, 'ARI'],
#   [826, 106, 1998, 'ATL'],
#   [817, 79, 1998, 'BAL'],
#   [876, 92, 1998, 'BOS'],
#   [861, 80, 1998, 'CHW'],
#   [831, 90, 1998, 'CHC'],
#   [750, 77, 1998, 'CIN'],
#   [850, 89, 1998, 'CLE'],
#   [826, 77, 1998, 'COL'],
#   [722, 65, 1998, 'DET'],
#   [667, 54, 1998, 'FLA'],
#   [874, 102, 1998, 'HOU'],
#   [714, 72, 1998, 'KCR'],
#   [669, 83, 1998, 'LAD'],
#   [707, 74, 1998, 'MIL'],
#   [734, 70, 1998, 'MIN'],
#   [644, 65, 1998, 'WSN'],
#   [965, 114, 1998, 'NYY'],
#   [706, 88, 1998, 'NYM'],
#   [804, 74, 1998, 'OAK'],
#   [713, 75, 1998, 'PHI'],
#   [650, 69, 1998, 'PIT'],
#   [749, 98, 1998, 'SDP'],
#   [859, 76, 1998, 'SEA'],
#   [845, 89, 1998, 'SFG'],
#   [810, 83, 1998, 'STL'],
#   [620, 63, 1998, 'TBD'],
#   [940, 88, 1998, 'TEX'],
#   [816, 88, 1998, 'TOR'],
#   [711, 70, 1999, 'ANA'],
#   [908, 100, 1999, 'ARI'],
#   [840, 103, 1999, 'ATL'],
#   [851, 78, 1999, 'BAL'],
#   [836, 94, 1999, 'BOS'],
#   [777, 75, 1999, 'CHW'],
#   [747, 67, 1999, 'CHC'],
#   [865, 96, 1999, 'CIN'],
#   [1009, 97, 1999, 'CLE'],
#   [906, 72, 1999, 'COL'],
#   [747, 69, 1999, 'DET'],
#   [691, 64, 1999, 'FLA'],
#   [823, 97, 1999, 'HOU'],
#   [856, 64, 1999, 'KCR'],
#   [793, 77, 1999, 'LAD'],
#   [815, 74, 1999, 'MIL'],
#   [686, 63, 1999, 'MIN'],
#   [718, 68, 1999, 'WSN'],
#   [900, 98, 1999, 'NYY'],
#   [853, 97, 1999, 'NYM'],
#   [893, 87, 1999, 'OAK'],
#   [841, 77, 1999, 'PHI'],
#   [775, 78, 1999, 'PIT'],
#   [710, 74, 1999, 'SDP'],
#   [859, 79, 1999, 'SEA'],
#   [872, 86, 1999, 'SFG'],
#   [809, 75, 1999, 'STL'],
#   [772, 69, 1999, 'TBD'],
#   [945, 95, 1999, 'TEX'],
#   [883, 84, 1999, 'TOR'],
#   [864, 82, 2000, 'ANA'],
#   [792, 85, 2000, 'ARI'],
#   [810, 95, 2000, 'ATL'],
#   [794, 74, 2000, 'BAL'],
#   [792, 85, 2000, 'BOS'],
#   [978, 95, 2000, 'CHW'],
#   [764, 65, 2000, 'CHC'],
#   [825, 85, 2000, 'CIN'],
#   [950, 90, 2000, 'CLE'],
#   [968, 82, 2000, 'COL'],
#   [823, 79, 2000, 'DET'],
#   [731, 79, 2000, 'FLA'],
#   [938, 72, 2000, 'HOU'],
#   [879, 77, 2000, 'KCR'],
#   [798, 86, 2000, 'LAD'],
#   [740, 73, 2000, 'MIL'],
#   [748, 69, 2000, 'MIN'],
#   [738, 67, 2000, 'WSN'],
#   [871, 87, 2000, 'NYY'],
#   [807, 94, 2000, 'NYM'],
#   [947, 91, 2000, 'OAK'],
#   [708, 65, 2000, 'PHI'],
#   [793, 69, 2000, 'PIT'],
#   [752, 76, 2000, 'SDP'],
#   [907, 91, 2000, 'SEA'],
#   [925, 97, 2000, 'SFG'],
#   [887, 95, 2000, 'STL'],
#   [733, 69, 2000, 'TBD'],
#   [848, 71, 2000, 'TEX'],
#   [861, 83, 2000, 'TOR'],
#   [691, 75, 2001, 'ANA'],
#   [818, 92, 2001, 'ARI'],
#   [729, 88, 2001, 'ATL'],
#   [687, 63, 2001, 'BAL'],
#   [772, 82, 2001, 'BOS'],
#   [798, 83, 2001, 'CHW'],
#   [777, 88, 2001, 'CHC'],
#   [735, 66, 2001, 'CIN'],
#   [897, 91, 2001, 'CLE'],
#   [923, 73, 2001, 'COL'],
#   [724, 66, 2001, 'DET'],
#   [742, 76, 2001, 'FLA'],
#   [847, 93, 2001, 'HOU'],
#   [729, 65, 2001, 'KCR'],
#   [758, 86, 2001, 'LAD'],
#   [740, 68, 2001, 'MIL'],
#   [771, 85, 2001, 'MIN'],
#   [670, 68, 2001, 'WSN'],
#   [804, 95, 2001, 'NYY'],
#   [642, 82, 2001, 'NYM'],
#   [884, 102, 2001, 'OAK'],
#   [746, 86, 2001, 'PHI'],
#   [657, 62, 2001, 'PIT'],
#   [789, 79, 2001, 'SDP'],
#   [927, 116, 2001, 'SEA'],
#   [799, 90, 2001, 'SFG'],
#   [814, 93, 2001, 'STL'],
#   [672, 62, 2001, 'TBD'],
#   [890, 73, 2001, 'TEX'],
#   [767, 80, 2001, 'TOR'],
#   [851, 99, 2002, 'ANA'],
#   [819, 98, 2002, 'ARI'],
#   [708, 101, 2002, 'ATL'],
#   [667, 67, 2002, 'BAL'],
#   [859, 93, 2002, 'BOS'],
#   [856, 81, 2002, 'CHW'],
#   [706, 67, 2002, 'CHC'],
#   [709, 78, 2002, 'CIN'],
#   [739, 74, 2002, 'CLE'],
#   [778, 73, 2002, 'COL'],
#   [575, 55, 2002, 'DET'],
#   [699, 79, 2002, 'FLA'],
#   [749, 84, 2002, 'HOU'],
#   [737, 62, 2002, 'KCR'],
#   [713, 92, 2002, 'LAD'],
#   [627, 56, 2002, 'MIL'],
#   [768, 94, 2002, 'MIN'],
#   [735, 83, 2002, 'WSN'],
#   [897, 103, 2002, 'NYY'],
#   [690, 75, 2002, 'NYM'],
#   [800, 103, 2002, 'OAK'],
#   [710, 80, 2002, 'PHI'],
#   [641, 72, 2002, 'PIT'],
#   [662, 66, 2002, 'SDP'],
#   [814, 93, 2002, 'SEA'],
#   [783, 95, 2002, 'SFG'],
#   [787, 97, 2002, 'STL'],
#   [673, 55, 2002, 'TBD'],
#   [843, 72, 2002, 'TEX'],
#   [813, 78, 2002, 'TOR'],
#   [736, 77, 2003, 'ANA'],
#   [717, 84, 2003, 'ARI'],
#   [907, 101, 2003, 'ATL'],
#   [743, 71, 2003, 'BAL'],
#   [961, 95, 2003, 'BOS'],
#   [791, 86, 2003, 'CHW'],
#   [724, 88, 2003, 'CHC'],
#   [694, 69, 2003, 'CIN'],
#   [699, 68, 2003, 'CLE'],
#   [853, 74, 2003, 'COL'],
#   [591, 43, 2003, 'DET'],
#   [751, 91, 2003, 'FLA'],
#   [805, 87, 2003, 'HOU'],
#   [836, 83, 2003, 'KCR'],
#   [574, 85, 2003, 'LAD'],
#   [714, 68, 2003, 'MIL'],
#   [801, 90, 2003, 'MIN'],
#   [711, 83, 2003, 'WSN'],
#   [877, 101, 2003, 'NYY'],
#   [642, 66, 2003, 'NYM'],
#   [768, 96, 2003, 'OAK'],
#   [791, 86, 2003, 'PHI'],
#   [753, 75, 2003, 'PIT'],
#   [678, 64, 2003, 'SDP'],
#   [795, 93, 2003, 'SEA'],
#   [755, 100, 2003, 'SFG'],
#   [876, 85, 2003, 'STL'],
#   [715, 63, 2003, 'TBD'],
#   [826, 71, 2003, 'TEX'],
#   [894, 86, 2003, 'TOR'],
#   [836, 92, 2004, 'ANA'],
#   [615, 51, 2004, 'ARI'],
#   [803, 96, 2004, 'ATL'],
#   [842, 78, 2004, 'BAL'],
#   [949, 98, 2004, 'BOS'],
#   [865, 83, 2004, 'CHW'],
#   [789, 89, 2004, 'CHC'],
#   [750, 76, 2004, 'CIN'],
#   [858, 80, 2004, 'CLE'],
#   [833, 68, 2004, 'COL'],
#   [827, 72, 2004, 'DET'],
#   [718, 83, 2004, 'FLA'],
#   [803, 92, 2004, 'HOU'],
#   [720, 58, 2004, 'KCR'],
#   [761, 93, 2004, 'LAD'],
#   [634, 67, 2004, 'MIL'],
#   [780, 92, 2004, 'MIN'],
#   [635, 67, 2004, 'WSN'],
#   [897, 101, 2004, 'NYY'],
#   [684, 71, 2004, 'NYM'],
#   [793, 91, 2004, 'OAK'],
#   [840, 86, 2004, 'PHI'],
#   [680, 72, 2004, 'PIT'],
#   [768, 87, 2004, 'SDP'],
#   [698, 63, 2004, 'SEA'],
#   [850, 91, 2004, 'SFG'],
#   [855, 105, 2004, 'STL'],
#   [714, 70, 2004, 'TBD'],
#   [860, 89, 2004, 'TEX'],
#   [719, 67, 2004, 'TOR'],
#   [696, 77, 2005, 'ARI'],
#   [769, 90, 2005, 'ATL'],
#   [729, 74, 2005, 'BAL'],
#   [910, 95, 2005, 'BOS'],
#   [741, 99, 2005, 'CHW'],
#   [703, 79, 2005, 'CHC'],
#   [820, 73, 2005, 'CIN'],
#   [790, 93, 2005, 'CLE'],
#   [740, 67, 2005, 'COL'],
#   [723, 71, 2005, 'DET'],
#   [717, 83, 2005, 'FLA'],
#   [693, 89, 2005, 'HOU'],
#   [701, 56, 2005, 'KCR'],
#   [761, 95, 2005, 'ANA'],
#   [685, 71, 2005, 'LAD'],
#   [726, 81, 2005, 'MIL'],
#   [688, 83, 2005, 'MIN'],
#   [886, 95, 2005, 'NYY'],
#   [722, 83, 2005, 'NYM'],
#   [772, 88, 2005, 'OAK'],
#   [807, 88, 2005, 'PHI'],
#   [680, 67, 2005, 'PIT'],
#   [684, 82, 2005, 'SDP'],
#   [699, 69, 2005, 'SEA'],
#   [649, 75, 2005, 'SFG'],
#   [805, 100, 2005, 'STL'],
#   [750, 67, 2005, 'TBD'],
#   [865, 79, 2005, 'TEX'],
#   [775, 80, 2005, 'TOR'],
#   [639, 81, 2005, 'WSN'],
#   [773, 76, 2006, 'ARI'],
#   [849, 79, 2006, 'ATL'],
#   [768, 70, 2006, 'BAL'],
#   [820, 86, 2006, 'BOS'],
#   [868, 90, 2006, 'CHW'],
#   [716, 66, 2006, 'CHC'],
#   [749, 80, 2006, 'CIN'],
#   [870, 78, 2006, 'CLE'],
#   [813, 76, 2006, 'COL'],
#   [822, 95, 2006, 'DET'],
#   [758, 78, 2006, 'FLA'],
#   [735, 82, 2006, 'HOU'],
#   [757, 62, 2006, 'KCR'],
#   [766, 89, 2006, 'ANA'],
#   [820, 88, 2006, 'LAD'],
#   [730, 75, 2006, 'MIL'],
#   [801, 96, 2006, 'MIN'],
#   [930, 97, 2006, 'NYY'],
#   [834, 97, 2006, 'NYM'],
#   [771, 93, 2006, 'OAK'],
#   [865, 85, 2006, 'PHI'],
#   [691, 67, 2006, 'PIT'],
#   [731, 88, 2006, 'SDP'],
#   [756, 78, 2006, 'SEA'],
#   [746, 76, 2006, 'SFG'],
#   [781, 83, 2006, 'STL'],
#   [689, 61, 2006, 'TBD'],
#   [835, 80, 2006, 'TEX'],
#   [809, 87, 2006, 'TOR'],
#   [746, 71, 2006, 'WSN'],
#   [712, 90, 2007, 'ARI'],
#   [810, 84, 2007, 'ATL'],
#   [756, 69, 2007, 'BAL'],
#   [867, 96, 2007, 'BOS'],
#   [693, 72, 2007, 'CHW'],
#   [752, 85, 2007, 'CHC'],
#   ...]}
